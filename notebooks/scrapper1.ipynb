# %% [markdown]
# # Scrapping first website
#
# **Beautiful Soup** is a Python library for pulling data out of HTML and XML files.

# %%
import pandas as pd
from random import randint
from time import sleep
import os.path

#from google.colab import drive
#drive.mount('/content/drive')

brand_file_exists = os.path.exists('../datasets/cars-data/brands.csv')
model1_file_exists = os.path.exists('../datasets/cars-data/models-1.csv')
model2_file_exists = os.path.exists('../datasets/cars-data/models-2.csv')
modelType_file_exists = os.path.exists('../datasets/cars-data/modelTypes.csv')
rawData_file_exists = os.path.exists('../datasets/cars-data/raw-data.csv')

scrapData = 0 # enable=1 or disable=0 to scrap the data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from bs4 import BeautifulSoup

Source = 'cars-data.com'
CarDataURL = "https://www.cars-data.com"
page = requests.get(CarDataURL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
def beautiful_soup(url):
    page = requests.get(url)
    return BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# - '\A\s+|\s+\Z' -> '' will act like strip() removing all leading and trailing whitespace:
#   - \A\s+ - matches 1 or more whitespace symbols at the start of the string
#   - | - or
#   - \s+\Z - matches 1 or more whitespace symbols at the end of the string
# - '\n' -> ' ' will replace any newline with a space.

# %%
def clean_data(df_text):
    return df_text.replace({ r'\A\s+|\s+\Z': '', '\n' : ' '}, regex=True, inplace=True)

# %% [markdown]
# **Function to verify a valid URL**

# %%
from urllib.parse import urlparse

def is_url(url):
    try:
        result = urlparse(url)
        return all([result.scheme, result.netloc])
    except ValueError:
        return False

# %%
results = soup.find("div", class_="footerbrands")
print(results.prettify())
# Out:
# <div class="row footerbrands">
#  <a class="a_footer" href="/en/abarth" title="Abarth">
#   Abarth
#  </a>
#  <a class="a_footer" href="/en/aiways" title="Aiways">
#   Aiways
#  </a>
#  <a class="a_footer" href="/en/alfa-romeo" title="Alfa Romeo">
#   Alfa Romeo
#  </a>
#  <a class="a_footer" href="/en/alpine" title="Alpine">
#   Alpine
#  </a>
#  <a class="a_footer" href="/en/asia-motors" title="Asia Motors">
#   Asia Motors
#  </a>
#  <a class="a_footer" href="/en/aston-martin" title="Aston Martin">
#   Aston Martin
#  </a>
#  <a class="a_footer" href="/en/audi" title="Audi">
#   Audi
#  </a>
#  <a class="a_footer" href="/en/austin" title="Austin">
#   Austin
#  </a>
#  <a class="a_footer" href="/en/autobianchi" title="Autobianchi">
#   Autobianchi
#  </a>
#  <a class="a_footer" href="/en/bentley" title="Bentley">
#   Bentley
#  </a>
#  <a class="a_footer" href="/en/bmw" title="BMW">
#   BMW
#  </a>
#  <a class="a_footer" href="/en/bugatti" title="Bugatti">
#   Bugatti
#  </a>
#  <a class="a_footer" href="/en/buick" title="Buick">
#   Buick
#  </a>
#  <a class="a_footer" href="/en/cadillac" title="Cadillac">
#   Cadillac
#  </a>
#  <a class="a_footer" href="/en/carver" title="Carver">
#   Carver
#  </a>
#  <a class="a_footer" href="/en/chevrolet" title="Chevrolet">
#   Chevrolet
#  </a>
#  <a class="a_footer" href="/en/chrysler" title="Chrysler">
#   Chrysler
#  </a>
#  <a class="a_footer" href="/en/citroen" title="Citroen">
#   Citroen
#  </a>
#  <a class="a_footer" href="/en/corvette" title="Corvette">
#   Corvette
#  </a>
#  <a class="a_footer" href="/en/cupra" title="Cupra">
#   Cupra
#  </a>
#  <a class="a_footer" href="/en/dacia" title="Dacia">
#   Dacia
#  </a>
#  <a class="a_footer" href="/en/daewoo" title="Daewoo">
#   Daewoo
#  </a>
#  <a class="a_footer" href="/en/daihatsu" title="Daihatsu">
#   Daihatsu
#  </a>
#  <a class="a_footer" href="/en/daimler" title="Daimler">
#   Daimler
#  </a>
#  <a class="a_footer" href="/en/datsun" title="Datsun">
#   Datsun
#  </a>
#  <a class="a_footer" href="/en/dodge" title="Dodge">
#   Dodge
#  </a>
#  <a class="a_footer" href="/en/donkervoort" title="Donkervoort">
#   Donkervoort
#  </a>
#  <a class="a_footer" href="/en/ds" title="DS">
#   DS
#  </a>
#  <a class="a_footer" href="/en/ferrari" title="Ferrari">
#   Ferrari
#  </a>
#  <a class="a_footer" href="/en/fiat" title="Fiat">
#   Fiat
#  </a>
#  <a class="a_footer" href="/en/fisker" title="Fisker">
#   Fisker
#  </a>
#  <a class="a_footer" href="/en/ford" title="Ford">
#   Ford
#  </a>
#  <a class="a_footer" href="/en/fso" title="FSO">
#   FSO
#  </a>
#  <a class="a_footer" href="/en/galloper" title="Galloper">
#   Galloper
#  </a>
#  <a class="a_footer" href="/en/honda" title="Honda">
#   Honda
#  </a>
#  <a class="a_footer" href="/en/hummer" title="Hummer">
#   Hummer
#  </a>
#  <a class="a_footer" href="/en/hyundai" title="Hyundai">
#   Hyundai
#  </a>
#  <a class="a_footer" href="/en/infiniti" title="Infiniti">
#   Infiniti
#  </a>
#  <a class="a_footer" href="/en/innocenti" title="Innocenti">
#   Innocenti
#  </a>
#  <a class="a_footer" href="/en/iveco" title="Iveco">
#   Iveco
#  </a>
#  <a class="a_footer" href="/en/jaguar" title="Jaguar">
#   Jaguar
#  </a>
#  <a class="a_footer" href="/en/jeep" title="Jeep">
#   Jeep
#  </a>
#  <a class="a_footer" href="/en/josse" title="Josse">
#   Josse
#  </a>
#  <a class="a_footer" href="/en/kia" title="Kia">
#   Kia
#  </a>
#  <a class="a_footer" href="/en/lada" title="Lada">
#   Lada
#  </a>
#  <a class="a_footer" href="/en/lamborghini" title="Lamborghini">
#   Lamborghini
#  </a>
#  <a class="a_footer" href="/en/lancia" title="Lancia">
#   Lancia
#  </a>
#  <a class="a_footer" href="/en/land-rover" title="Land Rover">
#   Land Rover
#  </a>
#  <a class="a_footer" href="/en/landwind" title="Landwind">
#   Landwind
#  </a>
#  <a class="a_footer" href="/en/lexus" title="Lexus">
#   Lexus
#  </a>
#  <a class="a_footer" href="/en/lincoln" title="Lincoln">
#   Lincoln
#  </a>
#  <a class="a_footer" href="/en/lotus" title="Lotus">
#   Lotus
#  </a>
#  <a class="a_footer" href="/en/marcos" title="Marcos">
#   Marcos
#  </a>
#  <a class="a_footer" href="/en/maserati" title="Maserati">
#   Maserati
#  </a>
#  <a class="a_footer" href="/en/maybach" title="Maybach">
#   Maybach
#  </a>
#  <a class="a_footer" href="/en/mazda" title="Mazda">
#   Mazda
#  </a>
#  <a class="a_footer" href="/en/mclaren" title="McLaren">
#   McLaren
#  </a>
#  <a class="a_footer" href="/en/mega" title="Mega">
#   Mega
#  </a>
#  <a class="a_footer" href="/en/mercedes-benz" title="Mercedes-Benz">
#   Mercedes-Benz
#  </a>
#  <a class="a_footer" href="/en/mercury" title="Mercury">
#   Mercury
#  </a>
#  <a class="a_footer" href="/en/mg" title="MG">
#   MG
#  </a>
#  <a class="a_footer" href="/en/mini" title="Mini">
#   Mini
#  </a>
#  <a class="a_footer" href="/en/mitsubishi" title="Mitsubishi">
#   Mitsubishi
#  </a>
#  <a class="a_footer" href="/en/morgan" title="Morgan">
#   Morgan
#  </a>
#  <a class="a_footer" href="/en/morris" title="Morris">
#   Morris
#  </a>
#  <a class="a_footer" href="/en/nissan" title="Nissan">
#   Nissan
#  </a>
#  <a class="a_footer" href="/en/noble" title="Noble">
#   Noble
#  </a>
#  <a class="a_footer" href="/en/opel" title="Opel">
#   Opel
#  </a>
#  <a class="a_footer" href="/en/peugeot" title="Peugeot">
#   Peugeot
#  </a>
#  <a class="a_footer" href="/en/pgo" title="PGO">
#   PGO
#  </a>
#  <a class="a_footer" href="/en/polestar" title="Polestar">
#   Polestar
#  </a>
#  <a class="a_footer" href="/en/pontiac" title="Pontiac">
#   Pontiac
#  </a>
#  <a class="a_footer" href="/en/porsche" title="Porsche">
#   Porsche
#  </a>
#  <a class="a_footer" href="/en/princess" title="Princess">
#   Princess
#  </a>
#  <a class="a_footer" href="/en/renault" title="Renault">
#   Renault
#  </a>
#  <a class="a_footer" href="/en/rolls-royce" title="Rolls-Royce">
#   Rolls-Royce
#  </a>
#  <a class="a_footer" href="/en/rover" title="Rover">
#   Rover
#  </a>
#  <a class="a_footer" href="/en/saab" title="Saab">
#   Saab
#  </a>
#  <a class="a_footer" href="/en/seat" title="Seat">
#   Seat
#  </a>
#  <a class="a_footer" href="/en/skoda" title="Skoda">
#   Skoda
#  </a>
#  <a class="a_footer" href="/en/smart" title="Smart">
#   Smart
#  </a>
#  <a class="a_footer" href="/en/spectre" title="Spectre">
#   Spectre
#  </a>
#  <a class="a_footer" href="/en/ssangyong" title="Ssangyong">
#   Ssangyong
#  </a>
#  <a class="a_footer" href="/en/subaru" title="Subaru">
#   Subaru
#  </a>
#  <a class="a_footer" href="/en/suzuki" title="Suzuki">
#   Suzuki
#  </a>
#  <a class="a_footer" href="/en/talbot" title="Talbot">
#   Talbot
#  </a>
#  <a class="a_footer" href="/en/tesla" title="Tesla">
#   Tesla
#  </a>
#  <a class="a_footer" href="/en/think" title="Think">
#   Think
#  </a>
#  <a class="a_footer" href="/en/toyota" title="Toyota">
#   Toyota
#  </a>
#  <a class="a_footer" href="/en/triumph" title="Triumph">
#   Triumph
#  </a>
#  <a class="a_footer" href="/en/tvr" title="TVR">
#   TVR
#  </a>
#  <a class="a_footer" href="/en/volkswagen" title="Volkswagen">
#   Volkswagen
#  </a>
#  <a class="a_footer" href="/en/volvo" title="Volvo">
#   Volvo
#  </a>
#  <a class="a_footer" href="/en/yugo" title="Yugo">
#   Yugo
#  </a>
# </div>

# %% [markdown]
# # 1. Fetch all the brands

# %%
if(brand_file_exists == True and scrapData == 0):
    CarsData_brands_df = pd.read_csv ('../datasets/cars-data/brands.csv')
else:
    CarsData_brands_df = pd.DataFrame(columns=['make','InnerLink'])

    brands = results.find_all("a", class_="a_footer")
    for i, brand in enumerate(brands):
        inner_url = brand['href'] if (is_url(brand['href']) == True) else CarDataURL+brand['href']

        CarsData_brands_df.loc[i, ['make']] = brand.text.strip()
        CarsData_brands_df.loc[i, ['InnerLink']] = inner_url

# %%
display(CarsData_brands_df)

# save brands to CSV file after scrapping
if(scrapData == 1):
    CarsData_brands_df.to_csv('../datasets/cars-data/brands.csv', encoding='utf-8', index=False)
# Out:
#            make                                 InnerLink
# 0        Abarth       https://www.cars-data.com/en/abarth
# 1        Aiways       https://www.cars-data.com/en/aiways
# 2    Alfa Romeo   https://www.cars-data.com/en/alfa-romeo
# 3        Alpine       https://www.cars-data.com/en/alpine
# 4   Asia Motors  https://www.cars-data.com/en/asia-motors
# ..          ...                                       ...
# 89      Triumph      https://www.cars-data.com/en/triumph
# 90          TVR          https://www.cars-data.com/en/tvr
# 91   Volkswagen   https://www.cars-data.com/en/volkswagen
# 92        Volvo        https://www.cars-data.com/en/volvo
# 93         Yugo         https://www.cars-data.com/en/yugo
#
# [94 rows x 2 columns]

# %%
if(model1_file_exists == True and scrapData == 0):
    CarsData_models_df = pd.read_csv ('../datasets/cars-data/models-1.csv')
else:
    CarsData_models_df = pd.DataFrame(columns=['make','model','InnerLink'])

    for b, CD_brand in CarsData_brands_df.iterrows():
        print(CD_brand['make'], CD_brand['InnerLink'])
        m_soup = beautiful_soup(CD_brand['InnerLink'])
        results = m_soup.find("section", class_="models")

        models = results.find_all("a")
        for i, model in enumerate(models):
            inner_url = model['href'] if (is_url(model['href']) == True) else CarDataURL+model['href']

            CarsData_models_df.loc[b, ['make']] = CD_brand['make']
            CarsData_models_df.loc[b, ['model']] = model.text.strip()
            CarsData_models_df.loc[b, ['InnerLink']] = inner_url

        sleep(randint(3,7))
# Out:
# Abarth https://www.cars-data.com/en/abarth
# Aiways https://www.cars-data.com/en/aiways
# Alfa Romeo https://www.cars-data.com/en/alfa-romeo
# Alpine https://www.cars-data.com/en/alpine
# Asia Motors https://www.cars-data.com/en/asia-motors
# Aston Martin https://www.cars-data.com/en/aston-martin
# Audi https://www.cars-data.com/en/audi
# Austin https://www.cars-data.com/en/austin
# Autobianchi https://www.cars-data.com/en/autobianchi
# Bentley https://www.cars-data.com/en/bentley
# BMW https://www.cars-data.com/en/bmw
# Bugatti https://www.cars-data.com/en/bugatti
# Buick https://www.cars-data.com/en/buick
# Cadillac https://www.cars-data.com/en/cadillac
# Carver https://www.cars-data.com/en/carver
# Chevrolet https://www.cars-data.com/en/chevrolet
# Chrysler https://www.cars-data.com/en/chrysler
# Citroen https://www.cars-data.com/en/citroen
# Corvette https://www.cars-data.com/en/corvette
# Cupra https://www.cars-data.com/en/cupra
# Dacia https://www.cars-data.com/en/dacia
# Daewoo https://www.cars-data.com/en/daewoo
# Daihatsu https://www.cars-data.com/en/daihatsu
# Daimler https://www.cars-data.com/en/daimler
# Datsun https://www.cars-data.com/en/datsun
# Dodge https://www.cars-data.com/en/dodge
# Donkervoort https://www.cars-data.com/en/donkervoort
# DS https://www.cars-data.com/en/ds
# Ferrari https://www.cars-data.com/en/ferrari
# Fiat https://www.cars-data.com/en/fiat
# Fisker https://www.cars-data.com/en/fisker
# Ford https://www.cars-data.com/en/ford
# FSO https://www.cars-data.com/en/fso
# Galloper https://www.cars-data.com/en/galloper
# Honda https://www.cars-data.com/en/honda
# Hummer https://www.cars-data.com/en/hummer
# Hyundai https://www.cars-data.com/en/hyundai
# Infiniti https://www.cars-data.com/en/infiniti
# Innocenti https://www.cars-data.com/en/innocenti
# Iveco https://www.cars-data.com/en/iveco
# Jaguar https://www.cars-data.com/en/jaguar
# Jeep https://www.cars-data.com/en/jeep
# Josse https://www.cars-data.com/en/josse
# Kia https://www.cars-data.com/en/kia
# Lada https://www.cars-data.com/en/lada
# Lamborghini https://www.cars-data.com/en/lamborghini
# Lancia https://www.cars-data.com/en/lancia
# Land Rover https://www.cars-data.com/en/land-rover
# Landwind https://www.cars-data.com/en/landwind
# Lexus https://www.cars-data.com/en/lexus
# Lincoln https://www.cars-data.com/en/lincoln
# Lotus https://www.cars-data.com/en/lotus
# Marcos https://www.cars-data.com/en/marcos
# Maserati https://www.cars-data.com/en/maserati
# Maybach https://www.cars-data.com/en/maybach
# Mazda https://www.cars-data.com/en/mazda
# McLaren https://www.cars-data.com/en/mclaren
# Mega https://www.cars-data.com/en/mega
# Mercedes-Benz https://www.cars-data.com/en/mercedes-benz
# Mercury https://www.cars-data.com/en/mercury
# MG https://www.cars-data.com/en/mg
# Mini https://www.cars-data.com/en/mini
# Mitsubishi https://www.cars-data.com/en/mitsubishi
# Morgan https://www.cars-data.com/en/morgan
# Morris https://www.cars-data.com/en/morris
# Nissan https://www.cars-data.com/en/nissan
# Noble https://www.cars-data.com/en/noble
# Opel https://www.cars-data.com/en/opel
# Peugeot https://www.cars-data.com/en/peugeot
# PGO https://www.cars-data.com/en/pgo
# Polestar https://www.cars-data.com/en/polestar
# Pontiac https://www.cars-data.com/en/pontiac
# Porsche https://www.cars-data.com/en/porsche
# Princess https://www.cars-data.com/en/princess
# Renault https://www.cars-data.com/en/renault
# Rolls-Royce https://www.cars-data.com/en/rolls-royce
# Rover https://www.cars-data.com/en/rover
# Saab https://www.cars-data.com/en/saab
# Seat https://www.cars-data.com/en/seat
# Skoda https://www.cars-data.com/en/skoda
# Smart https://www.cars-data.com/en/smart
# Spectre https://www.cars-data.com/en/spectre
# Ssangyong https://www.cars-data.com/en/ssangyong
# Subaru https://www.cars-data.com/en/subaru
# Suzuki https://www.cars-data.com/en/suzuki
# Talbot https://www.cars-data.com/en/talbot
# Tesla https://www.cars-data.com/en/tesla
# Think https://www.cars-data.com/en/think
# Toyota https://www.cars-data.com/en/toyota
# Triumph https://www.cars-data.com/en/triumph
# TVR https://www.cars-data.com/en/tvr
# Volkswagen https://www.cars-data.com/en/volkswagen
# Volvo https://www.cars-data.com/en/volvo
# Yugo https://www.cars-data.com/en/yugo

# %%
clean_data(CarsData_models_df)
CarsData_models_df = CarsData_models_df[CarsData_models_df.model != '']
display(CarsData_models_df)

# save models to CSV file after scrapping
if(scrapData == 1):
    CarsData_models_df.to_csv('../datasets/cars-data/models-1.csv', encoding='utf-8', index=False)
# Out:
#            make                   model  \
# 0        Abarth       Abarth 595 Cabrio
# 1        Aiways               Aiways U5
# 2    Alfa Romeo    Alfa Romeo 4C Spider
# 3        Alpine             Alpine A110
# 4   Asia Motors      Asia Motors Rocsta
# ..          ...                     ...
# 89      Triumph       Triumph TR7 Coupe
# 90          TVR            TVR Chimaera
# 91   Volkswagen  Volkswagen Caddy Cargo
# 92        Volvo              Volvo XC60
# 93         Yugo              Yugo 45/55
#
#                                             InnerLink
# 0      https://www.cars-data.com/en/abarth/595-cabrio
# 1              https://www.cars-data.com/en/aiways/u5
# 2   https://www.cars-data.com/en/alfa-romeo/4c-spider
# 3            https://www.cars-data.com/en/alpine/a110
# 4     https://www.cars-data.com/en/asia-motors/rocsta
# ..                                                ...
# 89     https://www.cars-data.com/en/triumph/tr7-coupe
# 90          https://www.cars-data.com/en/tvr/chimaera
# 91  https://www.cars-data.com/en/volkswagen/caddy-...
# 92            https://www.cars-data.com/en/volvo/xc60
# 93            https://www.cars-data.com/en/yugo/45-55
#
# [94 rows x 3 columns]

# %%
if(model2_file_exists == True and scrapData == 0):
    CarsData_md_df = pd.read_csv ('../datasets/cars-data/models-2.csv')
else:
    CarsData_md_df = pd.DataFrame(columns=['make','model','ModelLink'])

    for m, CD_model_m in CarsData_models_df.iterrows():
        mm_soup = beautiful_soup(CD_model_m['InnerLink'])
        m_results = mm_soup.find_all("section", class_="models")

        m_models = m_results[0].find_all("a")
        for i, m_model in enumerate(m_models):
            inner_url = m_model['href'] if (is_url(m_model['href']) == True) else CarDataURL+m_model['href']
            print(inner_url)

            CarsData_md_df.loc[m, ['make']] = CD_model_m['make']
            CarsData_md_df.loc[m, ['model']] = m_model['title']
            CarsData_md_df.loc[m, ['ModelLink']] = inner_url

        sleep(randint(3,7))
# Out:
# https://www.cars-data.com/en/abarth
# https://www.cars-data.com/en/abarth-595-cabrio-2016/3562
# https://www.cars-data.com/en/aiways
# https://www.cars-data.com/en/aiways-u5-2020/4733
# https://www.cars-data.com/en/alfa-romeo
# https://www.cars-data.com/en/alfa-romeo-4c-spider-2015/3254
# https://www.cars-data.com/en/alpine
# https://www.cars-data.com/en/alpine-a110-2018/4517
# https://www.cars-data.com/en/asia-motors
# https://www.cars-data.com/en/asia-motors-rocsta-1993/3025
# https://www.cars-data.com/en/aston-martin
# https://www.cars-data.com/en/aston-martin-db11-coupe-2016/3563
# https://www.cars-data.com/en/audi
# https://www.cars-data.com/en/audi-rs5-sportback-2020/4625
# https://www.cars-data.com/en/audi-rs5-sportback-2019/4128
# https://www.cars-data.com/en/austin
# https://www.cars-data.com/en/austin-maestro-1983/3026
# https://www.cars-data.com/en/autobianchi
# https://www.cars-data.com/en/autobianchi-a112-1980/3035
# https://www.cars-data.com/en/bentley
# https://www.cars-data.com/en/bentley-continental-gt-convertible-2012/3273
# https://www.cars-data.com/en/bmw
# https://www.cars-data.com/en/bmw-8-series-cabrio-2019/4151
# https://www.cars-data.com/en/bugatti
# https://www.cars-data.com/en/bugatti-veyron-2005/325
# https://www.cars-data.com/en/buick
# https://www.cars-data.com/en/buick-park-avenue-1991/3036
# https://www.cars-data.com/en/cadillac
# https://www.cars-data.com/en/cadillac-ats-coupe-2015/3571
# https://www.cars-data.com/en/carver
# https://www.cars-data.com/en/carver-one-2007/3132
# https://www.cars-data.com/en/chevrolet
# https://www.cars-data.com/en/chevrolet-volt-2011/379
# https://www.cars-data.com/en/chrysler
# https://www.cars-data.com/en/chrysler-300c-touring-2004/381
# https://www.cars-data.com/en/citroen
# https://www.cars-data.com/en/citroen-a-c4-2020/4692
# https://www.cars-data.com/en/corvette
# https://www.cars-data.com/en/corvette-c6-coupe-2004/3037
# https://www.cars-data.com/en/cupra
# https://www.cars-data.com/en/cupra-leon-2020/4725
# https://www.cars-data.com/en/dacia
# https://www.cars-data.com/en/dacia-lodgy-2012/515
# https://www.cars-data.com/en/daewoo
# https://www.cars-data.com/en/daewoo-kalos-2004/523
# https://www.cars-data.com/en/daewoo-kalos-2002/522
# https://www.cars-data.com/en/daihatsu
# https://www.cars-data.com/en/daihatsu-sirion-2-2005/593
# https://www.cars-data.com/en/daimler
# https://www.cars-data.com/en/daimler-six-1994/3675
# https://www.cars-data.com/en/datsun
# https://www.cars-data.com/en/datsun-bluebird-combi-1980/3049
# https://www.cars-data.com/en/dodge
# https://www.cars-data.com/en/dodge-nitro-2007/605
# https://www.cars-data.com/en/donkervoort
# https://www.cars-data.com/en/donkervoort-d8-1993/607
# https://www.cars-data.com/en/ds
# https://www.cars-data.com/en/ds-ds7-crossback-2017/4363
# https://www.cars-data.com/en/ferrari
# https://www.cars-data.com/en/ferrari-f8-spider-2020/4601
# https://www.cars-data.com/en/fiat
# https://www.cars-data.com/en/fiat-500l-wagon-2017/4178
# https://www.cars-data.com/en/fisker
# https://www.cars-data.com/en/fisker-karma-2011/704
# https://www.cars-data.com/en/ford
# https://www.cars-data.com/en/ford-c-max-energi-2015/3417
# https://www.cars-data.com/en/fso
# https://www.cars-data.com/en/fso-classic-1988/3067
# https://www.cars-data.com/en/galloper
# https://www.cars-data.com/en/galloper-galloper-1998/3072
# https://www.cars-data.com/en/galloper-galloper-1998/3073
# https://www.cars-data.com/en/honda
# https://www.cars-data.com/en/honda-cr-z-2013/3828
# https://www.cars-data.com/en/honda-cr-z-2010/920
# https://www.cars-data.com/en/hummer
# https://www.cars-data.com/en/hummer-h2-2004/957
# https://www.cars-data.com/en/hyundai
# https://www.cars-data.com/en/hyundai-nexo-2018/4203
# https://www.cars-data.com/en/infiniti
# https://www.cars-data.com/en/infiniti-q70-2015/3316
# https://www.cars-data.com/en/infiniti-q70-2014/3315
# https://www.cars-data.com/en/innocenti
# https://www.cars-data.com/en/innocenti-90-120-1979/3074
# https://www.cars-data.com/en/iveco
# https://www.cars-data.com/en/iveco-daily-2014/4478
# https://www.cars-data.com/en/iveco-daily-2012/4449
# https://www.cars-data.com/en/jaguar
# https://www.cars-data.com/en/jaguar-f-pace-2020/4703
# https://www.cars-data.com/en/jaguar-f-pace-2015/3434
# https://www.cars-data.com/en/jeep
# https://www.cars-data.com/en/jeep-renegade-2018/4213
# https://www.cars-data.com/en/jeep-renegade-2014/3322
# https://www.cars-data.com/en/josse
# https://www.cars-data.com/en/josse-indigo-3000-1998/3075
# https://www.cars-data.com/en/kia
# https://www.cars-data.com/en/kia-e-niro-2019/4218
# https://www.cars-data.com/en/lada
# https://www.cars-data.com/en/lada-priora-2172-2010/3615
# https://www.cars-data.com/en/lamborghini
# https://www.cars-data.com/en/lamborghini-huraca-n-2014/3331
# https://www.cars-data.com/en/lancia
# https://www.cars-data.com/en/lancia-voyager-2011/1228
# https://www.cars-data.com/en/land-rover
# https://www.cars-data.com/en/land-rover-discovery-sport-2019/4233
# https://www.cars-data.com/en/land-rover-discovery-sport-2016/4506
# https://www.cars-data.com/en/land-rover-discovery-sport-2014/3332
# https://www.cars-data.com/en/landwind
# https://www.cars-data.com/en/landwind-landwind-2005/3023
# https://www.cars-data.com/en/lexus
# https://www.cars-data.com/en/lexus-ux-2019/4244
# https://www.cars-data.com/en/lincoln
# https://www.cars-data.com/en/lincoln-town-car-1998/3081
# https://www.cars-data.com/en/lincoln-town-car-1994/3080
# https://www.cars-data.com/en/lotus
# https://www.cars-data.com/en/lotus-exige-2013/3191
# https://www.cars-data.com/en/lotus-exige-2004/1305
# https://www.cars-data.com/en/lotus-exige-2000/1304
# https://www.cars-data.com/en/marcos
# https://www.cars-data.com/en/marcos-mantara-1994/3084
# https://www.cars-data.com/en/marcos-mantara-1994/3085
# https://www.cars-data.com/en/maserati
# https://www.cars-data.com/en/maserati-granturismo-2018/4247
# https://www.cars-data.com/en/maserati-granturismo-2007/1307
# https://www.cars-data.com/en/maybach
# https://www.cars-data.com/en/maybach-62-2002/1312
# https://www.cars-data.com/en/mazda
# https://www.cars-data.com/en/mazda-mx-5-rf-2017/3864
# https://www.cars-data.com/en/mclaren
# https://www.cars-data.com/en/mclaren-720s-2017/4372
# https://www.cars-data.com/en/mega
# https://www.cars-data.com/en/mega-tjaffer-1994/3086
# https://www.cars-data.com/en/mercedes-benz
# https://www.cars-data.com/en/mercedes-benz-esprinter-2020/4672
# https://www.cars-data.com/en/mercury
# https://www.cars-data.com/en/mercury-sable-1992/3089
# https://www.cars-data.com/en/mg
# https://www.cars-data.com/en/mg-zs-2019/4567
# https://www.cars-data.com/en/mg-zs-2004/1584
# https://www.cars-data.com/en/mg-zs-2004/1582
# https://www.cars-data.com/en/mini
# https://www.cars-data.com/en/mini-roadster-2012/1599
# https://www.cars-data.com/en/mitsubishi
# https://www.cars-data.com/en/mitsubishi-l200-double-cab-2020/4663
# https://www.cars-data.com/en/mitsubishi-l200-double-cab-2015/4662
# https://www.cars-data.com/en/morgan
# https://www.cars-data.com/en/morgan-aero-coupe-2012/3199
# https://www.cars-data.com/en/morris
# https://www.cars-data.com/en/morris-marina-1979/3095
# https://www.cars-data.com/en/morris-marina-1979/3096
# https://www.cars-data.com/en/nissan
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2019/4561
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2016/4498
# https://www.cars-data.com/en/noble
# https://www.cars-data.com/en/noble-m400-2005/3098
# https://www.cars-data.com/en/opel
# https://www.cars-data.com/en/opel-corsa-e-2019/4292
# https://www.cars-data.com/en/peugeot
# https://www.cars-data.com/en/peugeot-e-expert-combi-2020/4716
# https://www.cars-data.com/en/pgo
# https://www.cars-data.com/en/pgo-speedster-2-2005/3099
# https://www.cars-data.com/en/polestar
# https://www.cars-data.com/en/polestar-2-2020/4646
# https://www.cars-data.com/en/pontiac
# https://www.cars-data.com/en/pontiac-firebird-coupe-1994/3102
# https://www.cars-data.com/en/pontiac-firebird-coupe-1990/3101
# https://www.cars-data.com/en/porsche
# https://www.cars-data.com/en/porsche-panamera-sport-turismo-2020/4690
# https://www.cars-data.com/en/porsche-panamera-sport-turismo-2017/4307
# https://www.cars-data.com/en/princess
# https://www.cars-data.com/en/princess-2000-1978/3107
# https://www.cars-data.com/en/renault
# https://www.cars-data.com/en/renault-talisman-2020/4729
# https://www.cars-data.com/en/renault-talisman-2016/3513
# https://www.cars-data.com/en/rolls-royce
# https://www.cars-data.com/en/rolls-royce-wraith-2014/3225
# https://www.cars-data.com/en/rover
# https://www.cars-data.com/en/rover-75-tourer-2004/2269
# https://www.cars-data.com/en/rover-75-tourer-2001/2268
# https://www.cars-data.com/en/saab
# https://www.cars-data.com/en/saab-9-7x-2005/2304
# https://www.cars-data.com/en/seat
# https://www.cars-data.com/en/seat-tarraco-2019/4317
# https://www.cars-data.com/en/skoda
# https://www.cars-data.com/en/skoda-kamiq-2019/4570
# https://www.cars-data.com/en/smart
# https://www.cars-data.com/en/smart-forfour-2020/4616
# https://www.cars-data.com/en/smart-forfour-2014/3374
# https://www.cars-data.com/en/smart-forfour-2004/2408
# https://www.cars-data.com/en/spectre
# https://www.cars-data.com/en/spectre-r42-1997/3108
# https://www.cars-data.com/en/ssangyong
# https://www.cars-data.com/en/ssangyong-tivoli-2015/3530
# https://www.cars-data.com/en/subaru
# https://www.cars-data.com/en/subaru-xv-2017/4326
# https://www.cars-data.com/en/subaru-xv-2012/4041
# https://www.cars-data.com/en/suzuki
# https://www.cars-data.com/en/suzuki-vitara-2018/4330
# https://www.cars-data.com/en/suzuki-vitara-2015/3382
# https://www.cars-data.com/en/talbot
# https://www.cars-data.com/en/talbot-tagora-1981/3120
# https://www.cars-data.com/en/tesla
# https://www.cars-data.com/en/tesla-model-x-2016/3532
# https://www.cars-data.com/en/think
# https://www.cars-data.com/en/think-city-2009/2577
# https://www.cars-data.com/en/toyota
# https://www.cars-data.com/en/toyota-corolla-sedan-2019/4336
# https://www.cars-data.com/en/triumph
# https://www.cars-data.com/en/triumph-tr7-coupe-1979/3122
# https://www.cars-data.com/en/tvr
# https://www.cars-data.com/en/tvr-chimaera-1994/3124
# https://www.cars-data.com/en/volkswagen
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2020/4713
# https://www.cars-data.com/en/volvo
# https://www.cars-data.com/en/volvo-xc60-2017/4114
# https://www.cars-data.com/en/volvo-xc60-2013/3251
# https://www.cars-data.com/en/volvo-xc60-2008/2968
# https://www.cars-data.com/en/yugo
# https://www.cars-data.com/en/yugo-45-55-1983/3128

# %%
display(CarsData_md_df)

# save models to CSV file after scrapping
if(scrapData == 1):
    CarsData_md_df.to_csv('../datasets/cars-data/models-2.csv', encoding='utf-8', index=False)
# Out:
#            make                   model  \
# 0        Abarth       Abarth 595 Cabrio
# 1        Aiways               Aiways U5
# 2    Alfa Romeo    Alfa Romeo 4C Spider
# 3        Alpine             Alpine A110
# 4   Asia Motors      Asia Motors Rocsta
# ..          ...                     ...
# 89      Triumph       Triumph TR7 Coupe
# 90          TVR            TVR Chimaera
# 91   Volkswagen  Volkswagen Caddy Cargo
# 92        Volvo              Volvo XC60
# 93         Yugo              Yugo 45/55
#
#                                             ModelLink
# 0   https://www.cars-data.com/en/abarth-595-cabrio...
# 1    https://www.cars-data.com/en/aiways-u5-2020/4733
# 2   https://www.cars-data.com/en/alfa-romeo-4c-spi...
# 3   https://www.cars-data.com/en/alpine-a110-2018/...
# 4   https://www.cars-data.com/en/asia-motors-rocst...
# ..                                                ...
# 89  https://www.cars-data.com/en/triumph-tr7-coupe...
# 90  https://www.cars-data.com/en/tvr-chimaera-1994...
# 91  https://www.cars-data.com/en/volkswagen-caddy-...
# 92  https://www.cars-data.com/en/volvo-xc60-2008/2968
# 93  https://www.cars-data.com/en/yugo-45-55-1983/3128
#
# [94 rows x 3 columns]

# %%
scrapData = 0
if(modelType_file_exists == True and scrapData == 0):
    CD_mt_df = pd.read_csv ('../datasets/cars-data/modelTypes.csv')
else:
    CD_mt_df = pd.DataFrame(columns=['make','model','ModelType','ModelTypeLink'])
    j=0
    for t, CD_model_t in CarsData_md_df.iterrows():
        mt_soup = beautiful_soup(CD_model_t['ModelLink'])
        mt_results = mt_soup.find_all("section", class_="types")
        mt_results = mt_results[0].find("div", class_="col-8")

        mt_models = mt_results.find_all("a", class_=False) # get <a> tags which has no class attributes
        for i, mt_model in enumerate(mt_models):
            inner_url = mt_model['href'] if (is_url(mt_model['href']) == True) else CarDataURL+mt_model['href']

            CD_mt_df.loc[j, ['make']] = CD_model_t['make']
            CD_mt_df.loc[j, ['model']] = CD_model_t['model']
            CD_mt_df.loc[j, ['ModelType']] = mt_model['title']
            CD_mt_df.loc[j, ['ModelTypeLink']] = inner_url
            j=j+1


        sleep(randint(3,7))

# %%
display(CD_mt_df)

# save model types to CSV file after scrapping
if(scrapData == 1):
    CD_mt_df.to_csv('../datasets/cars-data/modelTypes.csv', encoding='utf-8', index=False)
# Out:
#        make              model  \
# 0    Abarth  Abarth 595 Cabrio
# 1    Abarth  Abarth 595 Cabrio
# 2    Abarth  Abarth 595 Cabrio
# 3    Abarth  Abarth 595 Cabrio
# 4    Abarth  Abarth 595 Cabrio
# ..      ...                ...
# 497   Volvo         Volvo XC60
# 498   Volvo         Volvo XC60
# 499   Volvo         Volvo XC60
# 500    Yugo         Yugo 45/55
# 501    Yugo         Yugo 45/55
#
#                                              ModelType  \
# 0           2016 Abarth 595 Cabrio 1.4 T-Jet 145 specs
# 1           2016 Abarth 595 Cabrio 1.4 T-Jet 145 specs
# 2    2016 Abarth 595 Cabrio 1.4 T-Jet 165 Turismo s...
# 3    2016 Abarth 595 Cabrio 1.4 T-Jet 165 Turismo s...
# 4    2016 Abarth 595 Cabrio 1.4 T-Jet 180 Competizi...
# ..                                                 ...
# 497              2008 Volvo XC60 D5 AWD Momentum specs
# 498                2008 Volvo XC60 D5 AWD Summum specs
# 499                2008 Volvo XC60 D5 AWD Summum specs
# 500                               1983 Yugo 45 E specs
# 501                               1983 Yugo 45 S specs
#
#                                          ModelTypeLink
# 0    https://www.cars-data.com/en/abarth-595-cabrio...
# 1    https://www.cars-data.com/en/abarth-595-cabrio...
# 2    https://www.cars-data.com/en/abarth-595-cabrio...
# 3    https://www.cars-data.com/en/abarth-595-cabrio...
# 4    https://www.cars-data.com/en/abarth-595-cabrio...
# ..                                                 ...
# 497  https://www.cars-data.com/en/volvo-xc60-d5-awd...
# 498  https://www.cars-data.com/en/volvo-xc60-d5-awd...
# 499  https://www.cars-data.com/en/volvo-xc60-d5-awd...
# 500  https://www.cars-data.com/en/yugo-45-e-specs/5...
# 501  https://www.cars-data.com/en/yugo-45-s-specs/5...
#
# [502 rows x 4 columns]

# %%
scrapData == 1
if(rawData_file_exists == True and scrapData == 0):
    CD_ms_df = pd.read_csv ('../datasets/cars-data/raw-data.csv')
else:
    all_cols = ['make','model','generation','year_from','year_to','series','trim',
                'body_type','load_height_mm','number_of_seats','length_mm','width_mm','height_mm',
                'wheelbase_mm','front_track_mm','rear_track_mm','curb_weight_kg','wheel_size_r14',
                'ground_clearance_mm','trailer_load_with_brakes_kg','payload_kg','back_track_width_mm',
                'front_track_width_mm','clearance_mm','full_weight_kg','front_rear_axle_load_kg',
                'max_trunk_capacity_l','cargo_compartment_length_width_height_mm',
                'cargo_volume_m3','minimum_trunk_capacity_l','maximum_torque_n_m','injection_type',
                'overhead_camshaft','cylinder_layout','number_of_cylinders','compression_ratio',
                'engine_type','valves_per_cylinder','boost_type','cylinder_bore_mm','stroke_cycle_mm',
                'engine_placement','cylinder_bore_and_stroke_cycle_mm','turnover_of_maximum_torque_rpm',
                'max_power_kw','presence_of_intercooler','capacity_cm3','engine_hp','engine_hp_rpm',
                'drive_wheels','bore_stroke_ratio','number_of_gears','turning_circle_m','transmission',
                'mixed_fuel_consumption_per_100_km_l','range_km','emission_standards',
                'fuel_tank_capacity_l','acceleration_0_100_km/h_s','max_speed_km_per_h',
                'city_fuel_per_100km_l','CO2_emissions_g/km','fuel_grade','highway_fuel_per_100km_l',
                'back_suspension','rear_brakes','front_brakes','front_suspension','steering_type',
                'car_class','country_of_origin','number_of_doors','safety_assessment','rating_name',
                'battery_capacity_KW_per_h','electric_range_km','charging_time_h']
    # CD_ms_df = pd.DataFrame(columns=['Year','Brand','Model','ModelType','Engine','FuelType','Power(kW)',
    #                              'DriveWheel', 'TopSpeed', 'EngineCapacity', 'Source'])
    
    CD_ms_df = pd.DataFrame(columns=all_cols)
    sj=0
    for s, CD_model_s in CD_mt_df.iterrows():

        ms_soup = beautiful_soup(CD_model_s['ModelTypeLink'])
        ms_results = ms_soup.find_all("table")

        #display(ms_results)
        print(CD_model_s['ModelTypeLink'])
        for t, table in enumerate(ms_results):
            spec_rows = table.find_all("tr", class_=True)
            for i, spec_row in enumerate(spec_rows):
                spec = spec_row.find_all("td", class_=True)

                CD_ms_df.loc[sj, ['make']] = CD_model_s['make']
                CD_ms_df.loc[sj, ['model']] = CD_model_s['model']
                #CD_ms_df.loc[sj, ['ModelType']] = CD_model_s['ModelType']
                
                generation =  spec[1].text.strip() if (spec[0].text.strip() == 'Engine/motor Type:') else ''
                if(generation != ''):
                    CD_ms_df.loc[sj, ['generation']] =  generation

                year_from = CD_model_s['ModelType'].split()
                CD_ms_df.loc[sj, ['year_from']] = year_from[0]

                year_to = CD_model_s['ModelType'].split()
                CD_ms_df.loc[sj+t, ['year_to']] = year_from[0]
                
                trim =  spec[1].text.strip() if (spec[0].text.strip() == 'Trim:') else ''
                if(trim != ''):
                    CD_ms_df.loc[sj, ['trim']] =  trim

                body_type =  spec[1].text.strip() if (spec[0].text.strip() == 'Body Type:') else ''
                if(body_type != ''):
                    CD_ms_df.loc[sj, ['body_type']] =  body_type

                load_height_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Height (mm):') else ''
                if(load_height_mm != ''):
                    CD_ms_df.loc[sj, ['load_height_mm']] =  load_height_mm

                number_of_seats =  spec[1].text.strip() if (spec[0].text.strip() == 'Number Of Seats:') else ''
                if(number_of_seats != ''):
                    CD_ms_df.loc[sj, ['number_of_seats']] =  number_of_seats

                length_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Length:') else ''
                if(length_mm != ''):
                    CD_ms_df.loc[sj, ['length_mm']] =  length_mm

                width_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Width:') else ''
                if(width_mm != ''):
                    CD_ms_df.loc[sj, ['width_mm']] =  width_mm

                height_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Height:') else ''
                if(height_mm != ''):
                    CD_ms_df.loc[sj, ['height_mm']] =  height_mm

                wheelbase_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Wheel Base:') else ''
                if(wheelbase_mm != ''):
                    CD_ms_df.loc[sj, ['wheelbase_mm']] =  wheelbase_mm

                front_track_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Front Tire Size:') else ''
                if(front_track_mm != ''):
                    CD_ms_df.loc[sj, ['front_track_mm']] =  front_track_mm

                rear_track_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Rear Tire Size:') else ''
                if(rear_track_mm != ''):
                    CD_ms_df.loc[sj, ['rear_track_mm']] =  rear_track_mm

                curb_weight_kg =  spec[1].text.strip() if (spec[0].text.strip() == 'Curb Weight:') else ''
                if(curb_weight_kg != ''):
                    CD_ms_df.loc[sj, ['curb_weight_kg']] =  curb_weight_kg

                wheel_size_r14 =  spec[1].text.strip() if (spec[0].text.strip() == 'Wheel Size:') else ''
                if(wheel_size_r14 != ''):
                    CD_ms_df.loc[sj, ['wheel_size_r14']] =  wheel_size_r14

                ground_clearance_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Ground Clearance:') else ''
                if(ground_clearance_mm != ''):
                    CD_ms_df.loc[sj, ['ground_clearance_mm']] =  ground_clearance_mm

                trailer_load_with_brakes_kg =  spec[1].text.strip() if (spec[0].text.strip() == 'Trailer with brakes (Kg):') else ''
                if(trailer_load_with_brakes_kg != ''):
                    CD_ms_df.loc[sj, ['trailer_load_with_brakes_kg']] =  trailer_load_with_brakes_kg

                payload_kg =  spec[1].text.strip() if (spec[0].text.strip() == 'Payload (Kg):') else ''
                if(payload_kg != ''):
                    CD_ms_df.loc[sj, ['payload_kg']] =  payload_kg

                front_track_width_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Front Track width (mm)') else ''
                if(front_track_width_mm != ''):
                    CD_ms_df.loc[sj, ['front_track_width_mm']] =  front_track_width_mm

                clearance_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Clearance (mm):') else ''
                if(clearance_mm != ''):
                    CD_ms_df.loc[sj, ['clearance_mm']] =  clearance_mm

                full_weight_kg =  spec[1].text.strip() if (spec[0].text.strip() == 'Full weight (Kg):') else ''
                if(full_weight_kg != ''):
                    CD_ms_df.loc[sj, ['full_weight_kg']] =  full_weight_kg

                front_rear_axle_load_kg =  spec[1].text.strip() if (spec[0].text.strip() == 'Front Rear axle load (kg):') else ''
                if(front_rear_axle_load_kg != ''):
                    CD_ms_df.loc[sj, ['front_rear_axle_load_kg']] =  front_rear_axle_load_kg

                max_trunk_capacity_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Max trunk capacity (L):') else ''
                if(max_trunk_capacity_l != ''):
                    CD_ms_df.loc[sj, ['max_trunk_capacity_l']] =  max_trunk_capacity_l

                cargo_compartment_length_width_height_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Cargo Compartment (mm):') else ''
                if(cargo_compartment_length_width_height_mm != ''):
                    CD_ms_df.loc[sj, ['cargo_compartment_length_width_height_mm']] =  cargo_compartment_length_width_height_mm

                cargo_volume_m3 =  spec[1].text.strip() if (spec[0].text.strip() == 'Cargo volume (m3):') else ''
                if(cargo_volume_m3 != ''):
                    CD_ms_df.loc[sj, ['cargo_volume_m3']] =  cargo_volume_m3


                minimum_trunk_capacity_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Min Trunk Capacity (L):') else ''
                if(minimum_trunk_capacity_l != ''):
                    CD_ms_df.loc[sj, ['minimum_trunk_capacity_l']] =  minimum_trunk_capacity_l


                maximum_torque_n_m =  spec[1].text.strip() if (spec[0].text.strip() == 'Max torque(nm):') else ''
                if(maximum_torque_n_m != ''):
                    CD_ms_df.loc[sj, ['maximum_torque_n_m']] =  maximum_torque_n_m


                injection_type =  spec[1].text.strip() if (spec[0].text.strip() == 'Injection type:') else ''
                if(injection_type != ''):
                    CD_ms_df.loc[sj, ['injection_type']] =  injection_type


                overhead_camshaft =  spec[1].text.strip() if (spec[0].text.strip() == 'Overhead camshaft:') else ''
                if(overhead_camshaft != ''):
                    CD_ms_df.loc[sj, ['overhead_camshaft']] =  overhead_camshaft


                cylinder_layout =  spec[1].text.strip() if (spec[0].text.strip() == 'Cylinder layout:') else ''
                if(cylinder_layout != ''):
                    CD_ms_df.loc[sj, ['cylinder_layout']] =  cylinder_layout


                number_of_cylinders =  spec[1].text.strip() if (spec[0].text.strip() == 'No. of cylinder:') else ''
                if(number_of_cylinders != ''):
                    CD_ms_df.loc[sj, ['number_of_cylinders']] =  number_of_cylinders


                compression_ratio =  spec[1].text.strip() if (spec[0].text.strip() == 'Compression ratio:') else ''
                if(compression_ratio != ''):
                    CD_ms_df.loc[sj, ['compression_ratio']] =  compression_ratio
                
                engine_type =  spec[1].text.strip() if (spec[0].text.strip() == 'Engine/motor Type:') else ''
                if(engine_type != ''):
                    CD_ms_df.loc[sj, ['engine_type']] =  engine_type

                valves_per_cylinder =  spec[1].text.strip() if (spec[0].text.strip() == 'Valves Per Cylinder:') else ''
                if(valves_per_cylinder != ''):
                    CD_ms_df.loc[sj, ['valves_per_cylinder']] =  valves_per_cylinder

                boost_type =  spec[1].text.strip() if (spec[0].text.strip() == 'Boost type:') else ''
                if(boost_type != ''):
                    CD_ms_df.loc[sj, ['boost_type']] =  boost_type

                cylinder_bore_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Cylinder bore (mm):') else ''
                if(cylinder_bore_mm != ''):
                    CD_ms_df.loc[sj, ['cylinder_bore_mm']] =  cylinder_bore_mm

                stroke_cycle_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Stroke cycle (mm):') else ''
                if(stroke_cycle_mm != ''):
                    CD_ms_df.loc[sj, ['stroke_cycle_mm']] =  stroke_cycle_mm

                engine_placement =  spec[1].text.strip() if (spec[0].text.strip() == 'Engine placement:') else ''
                if(engine_placement != ''):
                    CD_ms_df.loc[sj, ['engine_placement']] =  engine_placement

                cylinder_bore_and_stroke_cycle_mm =  spec[1].text.strip() if (spec[0].text.strip() == 'Bore X Stroke:') else ''
                if(cylinder_bore_and_stroke_cycle_mm != ''):
                    CD_ms_df.loc[sj, ['cylinder_bore_and_stroke_cycle_mm']] =  cylinder_bore_and_stroke_cycle_mm

                turnover_of_maximum_torque_rpm =  spec[1].text.strip() if (spec[0].text.strip() == 'Max Torque Rpm:') else ''
                if(turnover_of_maximum_torque_rpm != ''):
                    CD_ms_df.loc[sj, ['turnover_of_maximum_torque_rpm']] =  turnover_of_maximum_torque_rpm

                
                max_power_kw = spec[1].text.strip() if (spec[0].text.strip() == 'Total Max. Power (kW):') else ''
                if(max_power_kw != ''):
                    CD_ms_df.loc[sj, ['max_power_kw']] = max_power_kw

                presence_of_intercooler =  spec[1].text.strip() if (spec[0].text.strip() == 'Turbo:') else ''
                if(presence_of_intercooler != ''):
                    CD_ms_df.loc[sj, ['presence_of_intercooler']] =  presence_of_intercooler

                capacity_cm3 =  spec[1].text.strip() if (spec[0].text.strip() == 'Capacity (cm3):') else ''
                if(capacity_cm3 != ''):
                    CD_ms_df.loc[sj, ['capacity_cm3']] =  capacity_cm3

                
                engine_hp =  spec[1].text.strip() if (spec[0].text.strip() == 'Power (hp):') else ''
                if(engine_hp != ''):
                    CD_ms_df.loc[sj, ['engine_hp']] = engine_hp

                engine_hp_rpm =  spec[1].text.strip() if (spec[0].text.strip() == 'Max. Power Rpm:') else ''
                if(engine_hp_rpm != ''):
                    CD_ms_df.loc[sj, ['engine_hp_rpm']] =  engine_hp_rpm
                    
                drive_wheels = spec[1].text.strip() if (spec[0].text.strip() == 'Drive Wheel :') else ''
                if(drive_wheels != ''):
                    CD_ms_df.loc[sj, ['drive_wheels']] = drive_wheels

                bore_stroke_ratio =  spec[1].text.strip() if (spec[0].text.strip() == 'Bore X Stroke:') else ''
                if(bore_stroke_ratio != ''):
                    CD_ms_df.loc[sj, ['bore_stroke_ratio']] =  bore_stroke_ratio

                number_of_gears =  spec[1].text.strip() if (spec[0].text.strip() == 'No of gears:') else ''
                if(number_of_gears != ''):
                    CD_ms_df.loc[sj, ['number_of_gears']] =  number_of_gears

                turning_circle_m =  spec[1].text.strip() if (spec[0].text.strip() == 'Turning Circle :') else ''
                if(turning_circle_m != ''):
                    CD_ms_df.loc[sj, ['turning_circle_m']] =  turning_circle_m

                transmission =  spec[1].text.strip() if (spec[0].text.strip() == 'Transmission:') else ''
                if(transmission != ''):
                    CD_ms_df.loc[sj, ['transmission']] =  transmission

                mixed_fuel_consumption_per_100_km_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Practice Consumption Monitor:') else ''
                if(mixed_fuel_consumption_per_100_km_l != ''):
                    CD_ms_df.loc[sj, ['mixed_fuel_consumption_per_100_km_l']] =  mixed_fuel_consumption_per_100_km_l

                range_km =  spec[1].text.strip() if (spec[0].text.strip() == 'Range:') else ''
                if(range_km != ''):
                    CD_ms_df.loc[sj, ['range_km']] =  range_km

                emission_standards =  spec[1].text.strip() if (spec[0].text.strip() == 'Co2 Emissions:') else ''
                if(emission_standards != ''):
                    CD_ms_df.loc[sj, ['emission_standards']] =  emission_standards

                fuel_tank_capacity_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Fuel Tank Capacity:') else ''
                if(fuel_tank_capacity_l != ''):
                    CD_ms_df.loc[sj, ['fuel_tank_capacity_l']] =  fuel_tank_capacity_l

                acceleration_0_100_km =  spec[1].text.strip() if (spec[0].text.strip() == 'Acceleration 0-100 Km / H:') else ''
                if(acceleration_0_100_km != ''):
                    CD_ms_df.loc[sj, ['acceleration_0_100_km/h_s']] =  acceleration_0_100_km

                
                max_speed_km_per_h =  spec[1].text.strip() if (spec[0].text.strip() == 'Top Speed:') else ''
                if(max_speed_km_per_h != ''):
                    CD_ms_df.loc[sj, ['max_speed_km_per_h']] = max_speed_km_per_h

                city_fuel_per_100km_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Urban Consumption:') else ''
                if(city_fuel_per_100km_l != ''):
                    CD_ms_df.loc[sj, ['city_fuel_per_100km_l']] =  city_fuel_per_100km_l

                CO2_emissions_g =  spec[1].text.strip() if (spec[0].text.strip() == 'Co2 Emissions:') else ''
                if(CO2_emissions_g != ''):
                    CD_ms_df.loc[sj, ['CO2_emissions_g/km']] =  CO2_emissions_g

                fuel_grade =  spec[1].text.strip() if (spec[0].text.strip() == 'Fuel Grade:') else ''
                if(fuel_grade != ''):
                    CD_ms_df.loc[sj, ['fuel_grade']] =  fuel_grade

                highway_fuel_per_100km_l =  spec[1].text.strip() if (spec[0].text.strip() == 'Combined Consumption:') else ''
                if(highway_fuel_per_100km_l != ''):
                    CD_ms_df.loc[sj, ['highway_fuel_per_100km_l']] =  highway_fuel_per_100km_l

                back_suspension =  spec[1].text.strip() if (spec[0].text.strip() == 'Rear Suspension:') else ''
                if(back_suspension != ''):
                    CD_ms_df.loc[sj, ['back_suspension']] =  back_suspension

                rear_brakes =  spec[1].text.strip() if (spec[0].text.strip() == 'Rear Brakes:') else ''
                if(rear_brakes != ''):
                    CD_ms_df.loc[sj, ['rear_brakes']] =  rear_brakes

                front_brakes =  spec[1].text.strip() if (spec[0].text.strip() == 'Front Brakes:') else ''
                if(front_brakes != ''):
                    CD_ms_df.loc[sj, ['front_brakes']] =  front_brakes

                front_suspension =  spec[1].text.strip() if (spec[0].text.strip() == 'Front Suspension:') else ''
                if(front_suspension != ''):
                    CD_ms_df.loc[sj, ['front_suspension']] =  front_suspension

                steering_type =  spec[1].text.strip() if (spec[0].text.strip() == 'Steering Type:') else ''
                if(steering_type != ''):
                    CD_ms_df.loc[sj, ['steering_type']] =  steering_type

                car_class =  spec[1].text.strip() if (spec[0].text.strip() == 'Car class:') else ''
                if(car_class != ''):
                    CD_ms_df.loc[sj, ['car_class']] =  car_class

                country_of_origin =  spec[1].text.strip() if (spec[0].text.strip() == 'Country of origin:') else ''
                if(country_of_origin != ''):
                    CD_ms_df.loc[sj, ['country_of_origin']] =  country_of_origin

                number_of_doors =  spec[1].text.strip() if (spec[0].text.strip() == 'Body Type:') else ''
                if(number_of_doors != ''):
                    number_of_doors = number_of_doors.split(',')
                    CD_ms_df.loc[sj, ['number_of_doors']] =  number_of_doors[0]

                safety_assessment =  spec[1].text.strip() if (spec[0].text.strip() == 'Safety Assessment:') else ''
                if(safety_assessment != ''):
                    CD_ms_df.loc[sj, ['safety_assessment']] =  safety_assessment

                rating_name =  spec[1].text.strip() if (spec[0].text.strip() == 'Rating:') else ''
                if(rating_name != ''):
                    CD_ms_df.loc[sj, ['rating_name']] =  rating_name

                battery_capacity_KW_per_h =  spec[1].text.strip() if (spec[0].text.strip() == 'Battery Range:') else ''
                if(battery_capacity_KW_per_h != ''):
                    CD_ms_df.loc[sj, ['battery_capacity_KW_per_h']] =  battery_capacity_KW_per_h

                electric_range_km =  spec[1].text.strip() if (spec[0].text.strip() == 'Electric range (km):') else ''
                if(electric_range_km != ''):
                    CD_ms_df.loc[sj, ['electric_range_km']] =  electric_range_km

                charging_time_h =  spec[1].text.strip() if (spec[0].text.strip() == 'Charging time (h):') else ''
                if(charging_time_h != ''):
                    CD_ms_df.loc[sj, ['charging_time_h']] =  charging_time_h


        sleep(randint(3,7))
        sj=sj+1
# Out:
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-145-specs/73534
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-145-specs/73535
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-165-turismo-specs/73536
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-165-turismo-specs/73537
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-180-competizione-specs/73538
# https://www.cars-data.com/en/abarth-595-cabrio-1-4-t-jet-180-competizione-specs/73539
# https://www.cars-data.com/en/aiways-u5-standaard-specs/84688
# https://www.cars-data.com/en/aiways-u5-showroom-specs/84689
# https://www.cars-data.com/en/aiways-u5-premium-specs/84690
# https://www.cars-data.com/en/alfa-romeo-4c-spider-1-750-tbi-specs/66221
# https://www.cars-data.com/en/alpine-a110-pure-specs/85884
# https://www.cars-data.com/en/alpine-a110-legende-specs/85885
# https://www.cars-data.com/en/alpine-a110-premiere-edition-specs/85886
# https://www.cars-data.com/en/asia-motors-rocsta-1-8-softtop-specs/68781
# https://www.cars-data.com/en/asia-motors-rocsta-1-8-hardtop-specs/59624
# https://www.cars-data.com/en/asia-motors-rocsta-2-2-diesel-softtop-specs/68782
# https://www.cars-data.com/en/asia-motors-rocsta-2-2-diesel-hardtop-specs/59625
# https://www.cars-data.com/en/aston-martin-db11-5-2-v12-coupe-specs/73540
# https://www.cars-data.com/en/audi-rs5-sportback-2-9-tfsi-quattro-specs/80343
# https://www.cars-data.com/en/austin-maestro-1-3-special-specs/59627
# https://www.cars-data.com/en/austin-maestro-1-3-specs/59628
# https://www.cars-data.com/en/autobianchi-a112-junior-specs/59681
# https://www.cars-data.com/en/autobianchi-a112-elegante-specs/59682
# https://www.cars-data.com/en/autobianchi-a112-elite-specs/59683
# https://www.cars-data.com/en/autobianchi-a112-abarth-specs/59684
# https://www.cars-data.com/en/bentley-continental-gt-convertible-v8-specs/66597
# https://www.cars-data.com/en/bentley-continental-gt-convertible-w12-specs/66599
# https://www.cars-data.com/en/bmw-840i-cabrio-specs/80546
# https://www.cars-data.com/en/bmw-840i-xdrive-cabrio-specs/80547
# https://www.cars-data.com/en/bmw-m850i-xdrive-cabrio-specs/80548
# https://www.cars-data.com/en/bmw-m8-cabrio-specs/99082
# https://www.cars-data.com/en/bmw-m8-competition-cabrio-specs/99083
# https://www.cars-data.com/en/bmw-840d-xdrive-cabrio-specs/80549
# https://www.cars-data.com/en/bugatti-veyron-16-4-specs/8626
# https://www.cars-data.com/en/buick-park-avenue-specs/59685
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-elegance-specs/73563
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-luxury-specs/73564
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-performance-specs/73565
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-premium-specs/73566
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-awd-performance-specs/73567
# https://www.cars-data.com/en/cadillac-ats-coupe-2-0-t-awd-premium-specs/73568
# https://www.cars-data.com/en/cadillac-ats-v-coupe-specs/73569
# https://www.cars-data.com/en/cadillac-ats-v-coupe-premium-specs/73570
# https://www.cars-data.com/en/carver-one-specs/59946
# https://www.cars-data.com/en/chevrolet-volt-lt-specs/9024
# https://www.cars-data.com/en/chevrolet-volt-ltz-specs/9025
# https://www.cars-data.com/en/chrysler-300c-touring-2-7-v6-specs/9032
# https://www.cars-data.com/en/chrysler-300c-touring-3-5-v6-specs/9033
# https://www.cars-data.com/en/chrysler-300c-touring-3-5-v6-awd-specs/9034
# https://www.cars-data.com/en/chrysler-300c-touring-hemi-5-7-v8-specs/9035
# https://www.cars-data.com/en/chrysler-300c-touring-hemi-5-7-v8-awd-specs/9036
# https://www.cars-data.com/en/citroen-e-c4-50kwh-136-feel-specs/102212
# https://www.cars-data.com/en/citroen-e-c4-50kwh-136-feel-edition-specs/102213
# https://www.cars-data.com/en/citroen-e-c4-50kwh-136-shine-specs/102214
# https://www.cars-data.com/en/corvette-c6-coupe-specs/59687
# https://www.cars-data.com/en/corvette-c6-coupe-specs/59688
# https://www.cars-data.com/en/cupra-leon-1-4-e-hybrid-business-specs/103508
# https://www.cars-data.com/en/cupra-leon-1-4-e-hybrid-adrenaline-specs/103509
# https://www.cars-data.com/en/cupra-leon-1-4-e-hybrid-performance-specs/103510
# https://www.cars-data.com/en/cupra-leon-1-4-e-hybrid-copper-edition-specs/103511
# https://www.cars-data.com/en/dacia-lodgy-tce-115-ambiance-5p-specs/10995
# https://www.cars-data.com/en/dacia-lodgy-tce-115-ambiance-7p-specs/10996
# https://www.cars-data.com/en/dacia-lodgy-tce-115-laureate-5p-specs/10997
# https://www.cars-data.com/en/dacia-lodgy-tce-115-laureate-7p-specs/10998
# https://www.cars-data.com/en/dacia-lodgy-tce-115-prestige-5p-specs/10999
# https://www.cars-data.com/en/dacia-lodgy-tce-115-prestige-7p-specs/11000
# https://www.cars-data.com/en/daewoo-kalos-1-4-spirit-specs/11077
# https://www.cars-data.com/en/daewoo-kalos-1-4-style-specs/11078
# https://www.cars-data.com/en/daewoo-kalos-1-4-class-specs/11079
# https://www.cars-data.com/en/daihatsu-sirion-2-1-0-12v-dvvt-trend-specs/11465
# https://www.cars-data.com/en/daihatsu-sirion-2-1-0-12v-dvvt-premium-specs/11467
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-comfort-specs/11469
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-comfort-specs/11470
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-prestige-specs/11475
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-prestige-specs/11476
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-sport-specs/11481
# https://www.cars-data.com/en/daihatsu-sirion-2-1-3-16v-dvvt-sport-specs/11482
# https://www.cars-data.com/en/daimler-six-specs/74135
# https://www.cars-data.com/en/daimler-six-specs/74136
# https://www.cars-data.com/en/datsun-bluebird-combi-1800-gl-specs/59721
# https://www.cars-data.com/en/dodge-nitro-3-7-v6-4x4-se-specs/11575
# https://www.cars-data.com/en/dodge-nitro-3-7-v6-4x4-sxt-specs/11576
# https://www.cars-data.com/en/dodge-nitro-4-0-v6-4x4-r-t-specs/11577
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x2-se-specs/11578
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x4-se-specs/11579
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x4-se-specs/11580
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x4-sxt-specs/11581
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x4-sxt-specs/11582
# https://www.cars-data.com/en/dodge-nitro-2-8-crd-4x4-r-t-specs/11583
# https://www.cars-data.com/en/donkervoort-d8-zetec-specs/11585
# https://www.cars-data.com/en/donkervoort-d8-cosworth-specs/11599
# https://www.cars-data.com/en/ds-ds7-crossback-puretech-225-performance-line-specs/84580
# https://www.cars-data.com/en/ds-ds7-crossback-puretech-225-so-chic-specs/84582
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-drive-efficiency-chic-specs/84589
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-drive-efficiency-be-chic-specs/84590
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-drive-efficiency-business-specs/84591
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-drive-efficiency-so-chic-specs/84592
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-drive-efficiency-executive-specs/84593
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-be-chic-specs/84594
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-business-specs/84596
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-performance-line-specs/84598
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-so-chic-specs/84600
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-130-executive-specs/84602
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-be-chic-specs/84604
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-business-specs/84605
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-performance-line-specs/84606
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-so-chic-specs/84607
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-executive-specs/84608
# https://www.cars-data.com/en/ds-ds7-crossback-bluehdi-180-la-premiere-specs/84609
# https://www.cars-data.com/en/ferrari-f8-spider-specs/104708
# https://www.cars-data.com/en/fiat-500l-wagon-twinair-105-popstar-specs/105071
# https://www.cars-data.com/en/fiat-500l-wagon-twinair-105-lounge-specs/105072
# https://www.cars-data.com/en/fiat-500l-wagon-t-jet-120-lounge-specs/105073
# https://www.cars-data.com/en/fiat-500l-wagon-twinair-80-cng-popstar-specs/105074
# https://www.cars-data.com/en/fiat-500l-wagon-twinair-80-cng-lounge-specs/105075
# https://www.cars-data.com/en/fiat-500l-wagon-1-3-multijet-95-popstar-specs/105076
# https://www.cars-data.com/en/fisker-karma-ecostandard-specs/12898
# https://www.cars-data.com/en/fisker-karma-ecosport-specs/12899
# https://www.cars-data.com/en/fisker-karma-ecochic-specs/12900
# https://www.cars-data.com/en/ford-mustang-fastback-2-3-ecoboost-specs/81014
# https://www.cars-data.com/en/ford-mustang-fastback-2-3-ecoboost-specs/81015
# https://www.cars-data.com/en/ford-mustang-fastback-gt-5-0-v8-specs/81016
# https://www.cars-data.com/en/ford-mustang-fastback-gt-5-0-v8-specs/81017
# https://www.cars-data.com/en/fso-classic-1-5-sle-specs/59762
# https://www.cars-data.com/en/galloper-galloper-2-5-tc-specs/59784
# https://www.cars-data.com/en/galloper-galloper-2-5-tci-specs/59785
# https://www.cars-data.com/en/honda-cr-z-1-5-s-specs/17013
# https://www.cars-data.com/en/honda-cr-z-1-5-sport-specs/17014
# https://www.cars-data.com/en/honda-cr-z-1-5-gt-specs/17015
# https://www.cars-data.com/en/hummer-h2-6-0-v8-pure-specs/17179
# https://www.cars-data.com/en/hummer-h2-6-0-v8-adventure-specs/17180
# https://www.cars-data.com/en/hummer-h2-6-0-v8-exclusive-specs/17182
# https://www.cars-data.com/en/hyundai-nexo-fcev-specs/81151
# https://www.cars-data.com/en/hyundai-nexo-fcev-plus-pack-specs/81152
# https://www.cars-data.com/en/infiniti-q70-3-7-v6-s-premium-specs/67279
# https://www.cars-data.com/en/infiniti-q70-3-5-v6-hybrid-gt-specs/67280
# https://www.cars-data.com/en/infiniti-q70-3-5-v6-hybrid-gt-premium-specs/67281
# https://www.cars-data.com/en/infiniti-q70-3-0d-gt-specs/67282
# https://www.cars-data.com/en/infiniti-q70-3-0d-gt-premium-specs/67283
# https://www.cars-data.com/en/infiniti-q70-3-0d-s-specs/67284
# https://www.cars-data.com/en/infiniti-q70-3-0d-s-premium-specs/67285
# https://www.cars-data.com/en/innocenti-90-l-specs/59787
# https://www.cars-data.com/en/innocenti-120-l-specs/59788
# https://www.cars-data.com/en/innocenti-de-tomaso-specs/59790
# https://www.cars-data.com/en/iveco-daily-29l11v-3000-h1-2-3-specs/114693
# https://www.cars-data.com/en/iveco-daily-29l11v-3000-h2-2-3-specs/114694
# https://www.cars-data.com/en/iveco-daily-29l11v-3000l-h1-2-3-specs/114695
# https://www.cars-data.com/en/iveco-daily-29l11v-3000l-h2-2-3-specs/114696
# https://www.cars-data.com/en/iveco-daily-29l11v-3300-h2-2-3-specs/114697
# https://www.cars-data.com/en/iveco-daily-29l13v-3000-h1-2-3-specs/114698
# https://www.cars-data.com/en/iveco-daily-29l13v-3000-h2-2-3-specs/114699
# https://www.cars-data.com/en/iveco-daily-29l13v-3000l-h1-2-3-specs/114700
# https://www.cars-data.com/en/iveco-daily-29l13v-3000l-h2-2-3-specs/114701
# https://www.cars-data.com/en/iveco-daily-29l13v-3300-h2-2-3-specs/114702
# https://www.cars-data.com/en/iveco-daily-29l15v-3000-h1-2-3-specs/114703
# https://www.cars-data.com/en/iveco-daily-29l15v-3000-h2-2-3-specs/114704
# https://www.cars-data.com/en/iveco-daily-29l15v-3000l-h1-2-3-specs/114705
# https://www.cars-data.com/en/iveco-daily-29l15v-3000l-h2-2-3-specs/114706
# https://www.cars-data.com/en/iveco-daily-29l15v-3300-h2-2-3-specs/114707
# https://www.cars-data.com/en/iveco-daily-35s11v-3000-h1-2-3-specs/114708
# https://www.cars-data.com/en/iveco-daily-35s11v-3000-h2-2-3-specs/114709
# https://www.cars-data.com/en/iveco-daily-35s11v-3000l-h1-2-3-specs/114710
# https://www.cars-data.com/en/iveco-daily-35s11v-3000l-h2-2-3-specs/114711
# https://www.cars-data.com/en/iveco-daily-35s11v-3300-h2-2-3-specs/114712
# https://www.cars-data.com/en/iveco-daily-35s11v-3300-h3-2-3-specs/114713
# https://www.cars-data.com/en/iveco-daily-35s11v-3950-h2-2-3-specs/114714
# https://www.cars-data.com/en/iveco-daily-35s11v-3950-h3-2-3-specs/114715
# https://www.cars-data.com/en/iveco-daily-35s13v-3000-h1-2-3-specs/114716
# https://www.cars-data.com/en/iveco-daily-35s13v-3000-h2-2-3-specs/114717
# https://www.cars-data.com/en/iveco-daily-35s13v-3000l-h1-2-3-specs/114718
# https://www.cars-data.com/en/iveco-daily-35s13v-3000l-h2-2-3-specs/114719
# https://www.cars-data.com/en/iveco-daily-35s13v-3300-h2-2-3-specs/114720
# https://www.cars-data.com/en/iveco-daily-35s13v-3300-h3-2-3-specs/114721
# https://www.cars-data.com/en/iveco-daily-35s13v-3950-h2-2-3-specs/114722
# https://www.cars-data.com/en/iveco-daily-35s13v-3950-h3-2-3-specs/114723
# https://www.cars-data.com/en/iveco-daily-35s15v-3000-h1-2-3-specs/114724
# https://www.cars-data.com/en/iveco-daily-35s15v-3000-h2-2-3-specs/114725
# https://www.cars-data.com/en/iveco-daily-35s15v-3000l-h1-2-3-specs/114726
# https://www.cars-data.com/en/iveco-daily-35s15v-3000l-h2-2-3-specs/114727
# https://www.cars-data.com/en/iveco-daily-35s15v-3300-h2-2-3-specs/114728
# https://www.cars-data.com/en/iveco-daily-35s15v-3300-h3-2-3-specs/114729
# https://www.cars-data.com/en/iveco-daily-35s15v-3950-h2-2-3-specs/114730
# https://www.cars-data.com/en/iveco-daily-35s15v-3950-h3-2-3-specs/114731
# https://www.cars-data.com/en/iveco-daily-35s17v-3000-h1-3-0-specs/114732
# https://www.cars-data.com/en/iveco-daily-35s17v-3000-h2-3-0-specs/114733
# https://www.cars-data.com/en/iveco-daily-35s17v-3000l-h1-3-0-specs/114734
# https://www.cars-data.com/en/iveco-daily-35s17v-3000l-h2-3-0-specs/114735
# https://www.cars-data.com/en/iveco-daily-35s17v-3300-h2-3-0-specs/114736
# https://www.cars-data.com/en/iveco-daily-35s17v-3300-h3-3-0-specs/114737
# https://www.cars-data.com/en/iveco-daily-35s17v-3950-h2-3-0-specs/114738
# https://www.cars-data.com/en/iveco-daily-35s17v-3950-h3-3-0-specs/114739
# https://www.cars-data.com/en/iveco-daily-35s21v-3000-h1-3-0-specs/114740
# https://www.cars-data.com/en/iveco-daily-35s21v-3000-h2-3-0-specs/114741
# https://www.cars-data.com/en/iveco-daily-35s21v-3000l-h1-3-0-specs/114742
# https://www.cars-data.com/en/iveco-daily-35s21v-3000l-h2-3-0-specs/114743
# https://www.cars-data.com/en/iveco-daily-35s21v-3300-h2-3-0-specs/114744
# https://www.cars-data.com/en/iveco-daily-35s21v-3300-h3-3-0-specs/114745
# https://www.cars-data.com/en/iveco-daily-35s21v-3950-h2-3-0-specs/114746
# https://www.cars-data.com/en/iveco-daily-35s21v-3950-h3-3-0-specs/114747
# https://www.cars-data.com/en/iveco-daily-35s14gv-3300-h2-specs/114748
# https://www.cars-data.com/en/iveco-daily-35s14gv-3300-h3-specs/114749
# https://www.cars-data.com/en/iveco-daily-35s14gv-3950-h2-specs/114750
# https://www.cars-data.com/en/iveco-daily-35s14gv-3950-h3-specs/114751
# https://www.cars-data.com/en/jaguar-f-pace-35t-awd-pure-specs/70491
# https://www.cars-data.com/en/jaguar-f-pace-35t-awd-prestige-specs/70492
# https://www.cars-data.com/en/jaguar-f-pace-35t-awd-r-sport-specs/70493
# https://www.cars-data.com/en/jaguar-f-pace-35t-awd-portfolio-specs/70494
# https://www.cars-data.com/en/jaguar-f-pace-s-awd-specs/70495
# https://www.cars-data.com/en/jaguar-f-pace-s-awd-first-edition-specs/70496
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-pure-specs/70497
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-prestige-specs/70498
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-r-sport-specs/70499
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-portfolio-specs/70500
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-pure-specs/70501
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-pure-specs/70505
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-prestige-specs/70502
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-prestige-specs/70506
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-r-sport-specs/70503
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-r-sport-specs/70507
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-portfolio-specs/70504
# https://www.cars-data.com/en/jaguar-f-pace-20d-180hp-awd-portfolio-specs/70508
# https://www.cars-data.com/en/jaguar-f-pace-30d-awd-pure-specs/70509
# https://www.cars-data.com/en/jaguar-f-pace-30d-awd-prestige-specs/70510
# https://www.cars-data.com/en/jaguar-f-pace-30d-awd-r-sport-specs/70511
# https://www.cars-data.com/en/jaguar-f-pace-30d-awd-portfolio-specs/70512
# https://www.cars-data.com/en/jaguar-f-pace-30d-awd-first-edition-specs/70513
# https://www.cars-data.com/en/jeep-renegade-1-4-multiair-latitude-specs/67360
# https://www.cars-data.com/en/jeep-renegade-1-4-multiair-longitude-specs/67361
# https://www.cars-data.com/en/jeep-renegade-1-4-multiair-limited-specs/67363
# https://www.cars-data.com/en/jeep-renegade-1-4-multiair-opening-edition-specs/67365
# https://www.cars-data.com/en/jeep-renegade-1-6-multijet-sport-specs/67367
# https://www.cars-data.com/en/jeep-renegade-1-6-multijet-longitude-specs/67368
# https://www.cars-data.com/en/jeep-renegade-1-6-multijet-limited-specs/67369
# https://www.cars-data.com/en/jeep-renegade-1-6-multijet-opening-edition-specs/67370
# https://www.cars-data.com/en/jeep-renegade-2-0-multijet-awd-limited-specs/67371
# https://www.cars-data.com/en/jeep-renegade-2-0-multijet-awd-opening-edition-specs/67372
# https://www.cars-data.com/en/jeep-renegade-2-0-multijet-4wd-limited-specs/67373
# https://www.cars-data.com/en/jeep-renegade-2-0-multijet-4wd-trailhawk-specs/67374
# https://www.cars-data.com/en/josse-indigo-3000-specs/59791
# https://www.cars-data.com/en/kia-e-niro-64kwh-dynamicline-specs/81523
# https://www.cars-data.com/en/kia-e-niro-64kwh-executiveline-specs/81524
# https://www.cars-data.com/en/lada-priora-2172-1-6-specs/19646
# https://www.cars-data.com/en/lamborghini-huracan-lp610-4-specs/67416
# https://www.cars-data.com/en/lancia-voyager-3-6-v6-pentastar-gold-specs/20048
# https://www.cars-data.com/en/lancia-voyager-2-8-multijet-gold-specs/20051
# https://www.cars-data.com/en/land-rover-discovery-sport-si4-s-specs/67417
# https://www.cars-data.com/en/land-rover-discovery-sport-si4-se-specs/67418
# https://www.cars-data.com/en/land-rover-discovery-sport-si4-hse-specs/67419
# https://www.cars-data.com/en/land-rover-discovery-sport-si4-hse-luxury-specs/67420
# https://www.cars-data.com/en/land-rover-discovery-sport-ed4-s-specs/67421
# https://www.cars-data.com/en/land-rover-discovery-sport-ed4-e-capability-se-specs/67422
# https://www.cars-data.com/en/land-rover-discovery-sport-ed4-e-capability-hse-specs/67423
# https://www.cars-data.com/en/land-rover-discovery-sport-ed4-e-capability-hse-luxury-specs/67424
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-s-specs/67425
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-s-specs/67426
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-se-specs/67427
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-se-specs/67428
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-hse-specs/67429
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-hse-specs/67430
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-hse-luxury-specs/67431
# https://www.cars-data.com/en/land-rover-discovery-sport-td4-hse-luxury-specs/67432
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-s-specs/67433
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-s-specs/67434
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-se-specs/67435
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-se-specs/67436
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-hse-specs/67437
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-hse-specs/67438
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-hse-luxury-specs/67439
# https://www.cars-data.com/en/land-rover-discovery-sport-sd4-hse-luxury-specs/67440
# https://www.cars-data.com/en/landwind-landwind-2-0-2wd-specs/59616
# https://www.cars-data.com/en/landwind-landwind-2-4-2wd-specs/59618
# https://www.cars-data.com/en/landwind-landwind-2-4-4wd-specs/59619
# https://www.cars-data.com/en/landwind-landwind-2-8-diesel-2wd-specs/59620
# https://www.cars-data.com/en/landwind-landwind-2-8-diesel-4wd-specs/59621
# https://www.cars-data.com/en/lexus-ux-250h-specs/81963
# https://www.cars-data.com/en/lexus-ux-250h-business-line-specs/81964
# https://www.cars-data.com/en/lexus-ux-250h-first-edition-specs/81965
# https://www.cars-data.com/en/lexus-ux-250h-luxury-line-specs/81966
# https://www.cars-data.com/en/lexus-ux-250h-executive-line-specs/81967
# https://www.cars-data.com/en/lexus-ux-250h-awd-executive-line-specs/81968
# https://www.cars-data.com/en/lincoln-town-car-specs/59797
# https://www.cars-data.com/en/lotus-exige-specs/20770
# https://www.cars-data.com/en/marcos-mantara-spyder-specs/59802
# https://www.cars-data.com/en/maserati-granturismo-specs/20776
# https://www.cars-data.com/en/maybach-62-specs/20801
# https://www.cars-data.com/en/mazda-mx-5-rf-skyactiv-g-131-ts-specs/76272
# https://www.cars-data.com/en/mazda-mx-5-rf-skyactiv-g-131-ts-specs/76273
# https://www.cars-data.com/en/mazda-mx-5-rf-skyactiv-g-131-gt-m-specs/76274
# https://www.cars-data.com/en/mazda-mx-5-rf-skyactiv-g-160-gt-m-specs/76275
# https://www.cars-data.com/en/mazda-mx-5-rf-skyactiv-g-160-gt-m-specs/76276
# https://www.cars-data.com/en/mclaren-720s-specs/84618
# https://www.cars-data.com/en/mega-tjaffer-1-1i-cabrio-specs/59803
# https://www.cars-data.com/en/mega-tjaffer-1-4-cabrio-diesel-specs/59805
# https://www.cars-data.com/en/mercedes-benz-esprinter-gb-l2-specs/126492
# https://www.cars-data.com/en/mercury-sable-gs-specs/59810
# https://www.cars-data.com/en/mercury-sable-ls-specs/59811
# https://www.cars-data.com/en/mg-zs-120-specs/25581
# https://www.cars-data.com/en/mg-zs-120-specs/25582
# https://www.cars-data.com/en/mg-zs-180-specs/25583
# https://www.cars-data.com/en/mg-zs-115-idt-specs/25584
# https://www.cars-data.com/en/mini-roadster-cooper-specs/26118
# https://www.cars-data.com/en/mini-roadster-cooper-specs/26119
# https://www.cars-data.com/en/mini-roadster-cooper-s-specs/26120
# https://www.cars-data.com/en/mini-roadster-cooper-s-specs/26121
# https://www.cars-data.com/en/mini-roadster-john-cooper-works-specs/26122
# https://www.cars-data.com/en/mini-roadster-john-cooper-works-specs/26123
# https://www.cars-data.com/en/mini-roadster-cooper-sd-specs/26124
# https://www.cars-data.com/en/mini-roadster-cooper-sd-specs/26125
# https://www.cars-data.com/en/mitsubishi-l200-double-cab-2-4-di-d-cleartec-invite-specs/70761
# https://www.cars-data.com/en/mitsubishi-l200-double-cab-2-4-di-d-cleartec-intense-specs/70762
# https://www.cars-data.com/en/mitsubishi-l200-double-cab-2-4-di-d-instyle-specs/70763
# https://www.cars-data.com/en/morgan-aero-coupe-specs/62971
# https://www.cars-data.com/en/morgan-aero-coupe-specs/62972
# https://www.cars-data.com/en/morris-marina-1300-l-specs/59822
# https://www.cars-data.com/en/morris-marina-1300-hl-specs/59823
# https://www.cars-data.com/en/morris-marina-1700-hl-specs/59824
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2-3-dci-160-visia-specs/131222
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2-3-dci-160-acenta-specs/131223
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2-3-dci-160-optima-specs/131224
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2-3-dci-160-n-connecta-specs/131225
# https://www.cars-data.com/en/nissan-np300-navara-king-cab-2-3-dci-160-tekna-specs/131226
# https://www.cars-data.com/en/noble-m400-specs/59826
# https://www.cars-data.com/en/opel-corsa-e-11kw-edition-specs/136168
# https://www.cars-data.com/en/opel-corsa-e-11kw-elegance-specs/136170
# https://www.cars-data.com/en/opel-corsa-e-11kw-launch-edition-specs/83240
# https://www.cars-data.com/en/peugeot-e-expert-combi-compact-50kwh-specs/145005
# https://www.cars-data.com/en/peugeot-e-expert-combi-standard-50kwh-specs/145006
# https://www.cars-data.com/en/peugeot-e-expert-combi-standard-75kwh-specs/145007
# https://www.cars-data.com/en/peugeot-e-expert-combi-long-50kwh-specs/145008
# https://www.cars-data.com/en/peugeot-e-expert-combi-long-75kwh-specs/145009
# https://www.cars-data.com/en/pgo-speedster-2-specs/59827
# https://www.cars-data.com/en/pgo-speedster-2-vintage-specs/59828
# https://www.cars-data.com/en/pgo-speedster-2-classique-specs/59829
# https://www.cars-data.com/en/pgo-speedster-2-dynamique-specs/59830
# https://www.cars-data.com/en/pgo-speedster-2-executief-specs/59831
# https://www.cars-data.com/en/pgo-speedster-2-look-cevennes-specs/59832
# https://www.cars-data.com/en/polestar-2-intro-specs/145306
# https://www.cars-data.com/en/pontiac-firebird-coupe-specs/59834
# https://www.cars-data.com/en/pontiac-firebird-trans-am-specs/59835
# https://www.cars-data.com/en/porsche-panamera-4-sport-turismo-specs/83630
# https://www.cars-data.com/en/porsche-panamera-4-e-hybrid-sport-turismo-specs/83631
# https://www.cars-data.com/en/porsche-panamera-4s-sport-turismo-specs/83632
# https://www.cars-data.com/en/porsche-panamera-turbo-sport-turismo-specs/83634
# https://www.cars-data.com/en/porsche-panamera-4s-diesel-sport-turismo-specs/83636
# https://www.cars-data.com/en/princess-2000-specs/59855
# https://www.cars-data.com/en/renault-talisman-tce-150-intens-specs/71418
# https://www.cars-data.com/en/renault-talisman-tce-200-intens-specs/71419
# https://www.cars-data.com/en/renault-talisman-tce-200-initiale-paris-specs/71420
# https://www.cars-data.com/en/renault-talisman-dci-110-life-specs/71421
# https://www.cars-data.com/en/renault-talisman-dci-110-zen-specs/71422
# https://www.cars-data.com/en/renault-talisman-dci-110-zen-specs/71423
# https://www.cars-data.com/en/renault-talisman-dci-110-intens-specs/71424
# https://www.cars-data.com/en/renault-talisman-dci-110-intens-specs/71425
# https://www.cars-data.com/en/renault-talisman-dci-130-intens-specs/71426
# https://www.cars-data.com/en/renault-talisman-dci-130-intens-specs/71427
# https://www.cars-data.com/en/renault-talisman-dci-130-initiale-paris-specs/71428
# https://www.cars-data.com/en/renault-talisman-dci-160-intens-specs/71429
# https://www.cars-data.com/en/renault-talisman-dci-160-initiale-paris-specs/71430
# https://www.cars-data.com/en/renault-talisman-tce-150-zen-specs/71417
# https://www.cars-data.com/en/rolls-royce-wraith-specs/63310
# https://www.cars-data.com/en/rover-75-tourer-1-8-business-specs/41273
# https://www.cars-data.com/en/rover-75-tourer-1-8-specs/41275
# https://www.cars-data.com/en/rover-75-tourer-1-8-specs/41276
# https://www.cars-data.com/en/rover-75-tourer-1-8-club-specs/41279
# https://www.cars-data.com/en/rover-75-tourer-1-8-club-specs/41280
# https://www.cars-data.com/en/rover-75-tourer-2-0-v6-club-specs/41291
# https://www.cars-data.com/en/rover-75-tourer-2-0-v6-club-specs/41292
# https://www.cars-data.com/en/rover-75-tourer-2-0-v6-sterling-specs/41293
# https://www.cars-data.com/en/rover-75-tourer-2-0-v6-sterling-specs/41294
# https://www.cars-data.com/en/rover-75-tourer-2-5-v6-club-specs/41296
# https://www.cars-data.com/en/rover-75-tourer-2-5-v6-sterling-specs/41297
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-business-specs/41298
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-specs/41300
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-specs/41301
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-club-specs/41304
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-club-specs/41305
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-sterling-specs/41306
# https://www.cars-data.com/en/rover-75-tourer-2-0-cdt-sterling-specs/41307
# https://www.cars-data.com/en/saab-9-7x-4-2-specs/42774
# https://www.cars-data.com/en/saab-9-7x-5-3-v8-specs/42775
# https://www.cars-data.com/en/seat-tarraco-1-5-tsi-style-specs/84115
# https://www.cars-data.com/en/seat-tarraco-1-5-tsi-xcellence-specs/84116
# https://www.cars-data.com/en/seat-tarraco-2-0-tsi-4drive-xcellence-specs/84117
# https://www.cars-data.com/en/seat-tarraco-2-0-tdi-150hp-style-specs/84118
# https://www.cars-data.com/en/seat-tarraco-2-0-tdi-150hp-xcellence-specs/84119
# https://www.cars-data.com/en/seat-tarraco-2-0-tdi-150hp-4drive-style-specs/84120
# https://www.cars-data.com/en/seat-tarraco-2-0-tdi-150hp-4drive-xcellence-specs/84121
# https://www.cars-data.com/en/seat-tarraco-2-0-tdi-190hp-4drive-xcellence-specs/84122
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-95hp-greentech-active-specs/157081
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-116hp-greentech-active-specs/157091
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-116hp-greentech-ambition-specs/157092
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-116hp-greentech-ambition-specs/157093
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-116hp-greentech-sport-business-specs/157094
# https://www.cars-data.com/en/skoda-kamiq-1-0-tsi-116hp-greentech-sport-business-specs/157095
# https://www.cars-data.com/en/smart-forfour-1-1-blackbasic-specs/46064
# https://www.cars-data.com/en/smart-forfour-1-1-pulse-specs/46067
# https://www.cars-data.com/en/smart-forfour-1-1-passion-specs/46069
# https://www.cars-data.com/en/smart-forfour-1-3-pulse-specs/46073
# https://www.cars-data.com/en/smart-forfour-1-3-pulse-specs/46074
# https://www.cars-data.com/en/smart-forfour-1-3-passion-specs/46075
# https://www.cars-data.com/en/smart-forfour-1-3-passion-specs/46076
# https://www.cars-data.com/en/smart-forfour-1-5-pulse-specs/46077
# https://www.cars-data.com/en/smart-forfour-1-5-pulse-specs/46078
# https://www.cars-data.com/en/smart-forfour-1-5-passion-specs/46079
# https://www.cars-data.com/en/smart-forfour-1-5-passion-specs/46080
# https://www.cars-data.com/en/smart-forfour-1-5-sportstyle-specs/46081
# https://www.cars-data.com/en/smart-forfour-1-5-sportstyle-specs/46082
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-50kw-blackbasic-specs/46084
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-50kw-pulse-specs/46087
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-50kw-pulse-specs/46088
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-50kw-passion-specs/46089
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-50kw-passion-specs/46090
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-70kw-pulse-specs/46093
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-70kw-pulse-specs/46094
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-70kw-passion-specs/46095
# https://www.cars-data.com/en/smart-forfour-1-5-cdi-70kw-passion-specs/46096
# https://www.cars-data.com/en/spectre-r42-specs/59856
# https://www.cars-data.com/en/spectre-r42-s-specs/59857
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-crystal-2wd-specs/71665
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-crystal-2wd-specs/71666
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-quartz-2wd-specs/71667
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-quartz-2wd-specs/71668
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-sapphire-2wd-specs/71669
# https://www.cars-data.com/en/ssangyong-tivoli-1-6-sapphire-2wd-specs/71670
# https://www.cars-data.com/en/subaru-xv-2-0d-executive-specs/46828
# https://www.cars-data.com/en/subaru-xv-1-6i-luxury-specs/46818
# https://www.cars-data.com/en/subaru-xv-1-6i-luxury-specs/46819
# https://www.cars-data.com/en/subaru-xv-2-0i-luxury-specs/46820
# https://www.cars-data.com/en/subaru-xv-2-0i-luxury-specs/46821
# https://www.cars-data.com/en/subaru-xv-2-0i-luxury-plus-specs/46822
# https://www.cars-data.com/en/subaru-xv-2-0i-luxury-plus-specs/46823
# https://www.cars-data.com/en/subaru-xv-2-0i-executive-specs/46824
# https://www.cars-data.com/en/subaru-xv-2-0i-executive-specs/46825
# https://www.cars-data.com/en/subaru-xv-2-0d-luxury-specs/46826
# https://www.cars-data.com/en/subaru-xv-2-0d-luxury-plus-specs/46827
# https://www.cars-data.com/en/suzuki-vitara-1-6-comfort-specs/68017
# https://www.cars-data.com/en/suzuki-vitara-1-6-style-specs/70063
# https://www.cars-data.com/en/suzuki-vitara-1-6-exclusive-specs/68018
# https://www.cars-data.com/en/suzuki-vitara-1-6-exclusive-specs/70064
# https://www.cars-data.com/en/suzuki-vitara-1-6-high-executive-specs/68019
# https://www.cars-data.com/en/suzuki-vitara-1-6-high-executive-specs/70065
# https://www.cars-data.com/en/suzuki-vitara-1-6-allgrip-exclusive-specs/68020
# https://www.cars-data.com/en/suzuki-vitara-1-6-allgrip-exclusive-specs/70066
# https://www.cars-data.com/en/suzuki-vitara-1-6-allgrip-high-executive-specs/68021
# https://www.cars-data.com/en/suzuki-vitara-1-6-allgrip-high-executive-specs/70067
# https://www.cars-data.com/en/suzuki-vitara-1-4-s-boosterjet-specs/70068
# https://www.cars-data.com/en/suzuki-vitara-1-4-s-boosterjet-specs/70069
# https://www.cars-data.com/en/suzuki-vitara-1-4-allgrip-s-boosterjet-specs/70070
# https://www.cars-data.com/en/suzuki-vitara-1-4-allgrip-s-boosterjet-specs/70071
# https://www.cars-data.com/en/suzuki-vitara-1-6-diesel-exclusive-specs/68022
# https://www.cars-data.com/en/suzuki-vitara-1-6-diesel-high-executive-specs/68023
# https://www.cars-data.com/en/suzuki-vitara-1-6-diesel-allgrip-exclusive-specs/68024
# https://www.cars-data.com/en/suzuki-vitara-1-6-diesel-allgrip-high-executive-specs/68025
# https://www.cars-data.com/en/suzuki-vitara-1-6-diesel-allgrip-high-executive-specs/70072
# https://www.cars-data.com/en/talbot-tagora-2-2-gl-specs/59915
# https://www.cars-data.com/en/talbot-tagora-2-2-gls-specs/59916
# https://www.cars-data.com/en/talbot-tagora-2-2-gls-specs/59917
# https://www.cars-data.com/en/talbot-tagora-2-6-v6-sx-specs/59918
# https://www.cars-data.com/en/talbot-tagora-2-3-td-specs/59919
# https://www.cars-data.com/en/tesla-model-x-60d-specs/73365
# https://www.cars-data.com/en/tesla-model-x-75d-specs/71673
# https://www.cars-data.com/en/tesla-model-x-90d-specs/71674
# https://www.cars-data.com/en/tesla-model-x-p90d-specs/71675
# https://www.cars-data.com/en/tesla-model-x-p90d-signature-performance-specs/71676
# https://www.cars-data.com/en/tesla-model-x-100d-performance-ludicrous-specs/73367
# https://www.cars-data.com/en/think-city-specs/47378
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-active-specs/162734
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-business-specs/162735
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-first-edition-specs/162736
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-dynamic-specs/162737
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-business-plus-specs/162738
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-style-specs/162739
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-business-intro-specs/162740
# https://www.cars-data.com/en/toyota-corolla-sedan-1-8-hybrid-executive-specs/162742
# https://www.cars-data.com/en/triumph-tr7-coupe-specs/59923
# https://www.cars-data.com/en/tvr-chimaera-400-specs/59925
# https://www.cars-data.com/en/tvr-chimaera-500-specs/59927
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2-0-tdi-75hp-economy-business-specs/164861
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2-0-tdi-75hp-specs/164862
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2-0-tdi-102hp-specs/164863
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2-0-tdi-122hp-specs/164864
# https://www.cars-data.com/en/volkswagen-caddy-cargo-2-0-tdi-122hp-specs/164865
# https://www.cars-data.com/en/volvo-xc60-t6-awd-momentum-specs/57966
# https://www.cars-data.com/en/volvo-xc60-t6-awd-summum-specs/57967
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-specs/58008
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-specs/58009
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-kinetic-specs/58010
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-kinetic-specs/58011
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-momentum-specs/58012
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-momentum-specs/58013
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-summum-specs/58014
# https://www.cars-data.com/en/volvo-xc60-2-4d-awd-summum-specs/58015
# https://www.cars-data.com/en/volvo-xc60-d5-awd-specs/58026
# https://www.cars-data.com/en/volvo-xc60-d5-awd-specs/58027
# https://www.cars-data.com/en/volvo-xc60-d5-awd-kinetic-specs/58028
# https://www.cars-data.com/en/volvo-xc60-d5-awd-kinetic-specs/58029
# https://www.cars-data.com/en/volvo-xc60-d5-awd-momentum-specs/58030
# https://www.cars-data.com/en/volvo-xc60-d5-awd-momentum-specs/58031
# https://www.cars-data.com/en/volvo-xc60-d5-awd-summum-specs/58032
# https://www.cars-data.com/en/volvo-xc60-d5-awd-summum-specs/58033
# https://www.cars-data.com/en/yugo-45-e-specs/59933
# https://www.cars-data.com/en/yugo-45-s-specs/59934

# %%
#CD_ms_df = CD_ms_df.dropna()
display(CD_ms_df)

# save model types to CSV file after scrapping
if(scrapData == 1):
    CD_ms_df.to_csv('../datasets/cars-data/raw-data.csv', encoding='utf-8', index=False)
# Out:
#        make              model   generation year_from year_to series trim  \
# 0    Abarth  Abarth 595 Cabrio  fuel engine      2016    2016    NaN  NaN
# 1    Abarth  Abarth 595 Cabrio  fuel engine      2016    2016    NaN  NaN
# 2    Abarth  Abarth 595 Cabrio  fuel engine      2016    2016    NaN  NaN
# 3    Abarth  Abarth 595 Cabrio  fuel engine      2016    2016    NaN  NaN
# 4    Abarth  Abarth 595 Cabrio  fuel engine      2016    2016    NaN  NaN
# ..      ...                ...          ...       ...     ...    ...  ...
# 516     NaN                NaN          NaN       NaN    1983    NaN  NaN
# 517     NaN                NaN          NaN       NaN    1983    NaN  NaN
# 518     NaN                NaN          NaN       NaN    1983    NaN  NaN
# 519     NaN                NaN          NaN       NaN    1983    NaN  NaN
# 520     NaN                NaN          NaN       NaN    1983    NaN  NaN
#
#                 body_type load_height_mm number_of_seats  ...  \
# 0    3-doors, convertible            NaN             NaN  ...
# 1    3-doors, convertible            NaN             NaN  ...
# 2    3-doors, convertible            NaN             NaN  ...
# 3    3-doors, convertible            NaN             NaN  ...
# 4    3-doors, convertible            NaN             NaN  ...
# ..                    ...            ...             ...  ...
# 516                   NaN            NaN             NaN  ...
# 517                   NaN            NaN             NaN  ...
# 518                   NaN            NaN             NaN  ...
# 519                   NaN            NaN             NaN  ...
# 520                   NaN            NaN             NaN  ...
#
#     front_suspension steering_type car_class country_of_origin  \
# 0       coil springs           NaN       NaN               NaN
# 1       coil springs           NaN       NaN               NaN
# 2       coil springs           NaN       NaN               NaN
# 3       coil springs           NaN       NaN               NaN
# 4       coil springs           NaN       NaN               NaN
# ..               ...           ...       ...               ...
# 516              NaN           NaN       NaN               NaN
# 517              NaN           NaN       NaN               NaN
# 518              NaN           NaN       NaN               NaN
# 519              NaN           NaN       NaN               NaN
# 520              NaN           NaN       NaN               NaN
#
#     number_of_doors safety_assessment rating_name battery_capacity_KW_per_h  \
# 0           3-doors               NaN         NaN                       NaN
# 1           3-doors               NaN         NaN                       NaN
# 2           3-doors               NaN         NaN                       NaN
# 3           3-doors               NaN         NaN                       NaN
# 4           3-doors               NaN         NaN                       NaN
# ..              ...               ...         ...                       ...
# 516             NaN               NaN         NaN                       NaN
# 517             NaN               NaN         NaN                       NaN
# 518             NaN               NaN         NaN                       NaN
# 519             NaN               NaN         NaN                       NaN
# 520             NaN               NaN         NaN                       NaN
#
#     electric_range_km charging_time_h
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ..                ...             ...
# 516               NaN             NaN
# 517               NaN             NaN
# 518               NaN             NaN
# 519               NaN             NaN
# 520               NaN             NaN
#
# [521 rows x 77 columns]
